# %% [markdown]
# ## Scraping

# %%
# !pip install requests beautifulsoup4 pandas matplotlib
# !pip install requests-html
# !pip install lxml_html_clean
# !pip install "lxml[html_clean]"
# !pip install playwright
# !playwright install
# !pip install tabulate
# Out:
# Requirement already satisfied: requests in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (4.13.4)
# Requirement already satisfied: pandas in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (2.2.3)
# Collecting matplotlib
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests) (3.4.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pandas) (2025.2)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from matplotlib) (24.2)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow>=8 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.58.1-cp39-cp39-macosx_10_9_universal2.whl (2.7 MB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.22.0)
# Requirement already satisfied: six>=1.5 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.58.1 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pyparsing-3.2.3
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.
# Collecting requests-html
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting bs4
#   Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting w3lib
#   Using cached w3lib-2.3.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: requests in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests-html) (2.32.3)
# Collecting fake-useragent
#   Using cached fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Collecting pyppeteer>=0.0.14
#   Using cached pyppeteer-2.0.0-py3-none-any.whl (82 kB)
# Collecting pyquery
#   Using cached pyquery-2.0.1-py3-none-any.whl (22 kB)
# Collecting parse
#   Using cached parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: certifi>=2023 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (2025.4.26)
# Collecting websockets<11.0,>=10.0
#   Using cached websockets-10.4-cp39-cp39-macosx_11_0_arm64.whl (97 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (4.67.1)
# Collecting appdirs<2.0.0,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pyee<12.0.0,>=11.0.0
#   Using cached pyee-11.1.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (8.7.0)
# Collecting urllib3<2.0.0,>=1.25.8
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Requirement already satisfied: zipp>=3.20 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.22.0)
# Requirement already satisfied: typing-extensions in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html) (4.13.2)
# Requirement already satisfied: beautifulsoup4 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from bs4->requests-html) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests-html) (2.7)
# Requirement already satisfied: importlib-resources>=6 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from fake-useragent->requests-html) (6.5.2)
# Requirement already satisfied: lxml>=2.1 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyquery->requests-html) (5.4.0)
# Collecting cssselect>=1.2.0
#   Using cached cssselect-1.3.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests->requests-html) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from requests->requests-html) (3.10)
# Installing collected packages: websockets, urllib3, pyee, cssselect, appdirs, w3lib, pyquery, pyppeteer, parse, fake-useragent, bs4, requests-html
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: pyee
#     Found existing installation: pyee 13.0.0
#     Uninstalling pyee-13.0.0:
#       Successfully uninstalled pyee-13.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# playwright 1.52.0 requires pyee<14,>=13, but you have pyee 11.1.1 which is incompatible.
# Successfully installed appdirs-1.4.4 bs4-0.0.2 cssselect-1.3.0 fake-useragent-2.2.0 parse-1.20.2 pyee-11.1.1 pyppeteer-2.0.0 pyquery-2.0.1 requests-html-0.10.0 urllib3-1.26.20 w3lib-2.3.1 websockets-10.4
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.
# Collecting lxml_html_clean
#   Using cached lxml_html_clean-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: lxml in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from lxml_html_clean) (5.4.0)
# Installing collected packages: lxml-html-clean
# Successfully installed lxml-html-clean-0.4.2
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: lxml[html_clean] in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (5.4.0)
# WARNING: lxml 5.4.0 does not provide the extra 'html_clean'
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: playwright in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (1.52.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from playwright) (3.2.2)
# Collecting pyee<14,>=13
#   Using cached pyee-13.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (from pyee<14,>=13->playwright) (4.13.2)
# Installing collected packages: pyee
#   Attempting uninstall: pyee
#     Found existing installation: pyee 11.1.1
#     Uninstalling pyee-11.1.1:
#       Successfully uninstalled pyee-11.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyppeteer 2.0.0 requires pyee<12.0.0,>=11.0.0, but you have pyee 13.0.0 which is incompatible.
# Successfully installed pyee-13.0.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: tabulate in /Users/macbook/Documents/Scraping/env/lib/python3.9/site-packages (0.9.0)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/macbook/Documents/Scraping/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.sebi.gov.in/sebiweb/other/OtherAction.do?doPmr=yes"

response = requests.get(url)
response.raise_for_status()

soup = BeautifulSoup(response.content, "html.parser")

select_pm = soup.find("select", {"name": "pmrId"})
if not select_pm:
    raise Exception("Portfolio Manager select box not found")

options = [(opt.get("value"), opt.text.strip()) for opt in select_pm.find_all("option") if opt.get("value")]

print("Portfolio Manager options (value, text):")
for value, text in options:
    print(f"{value} -> {text}")
# Out:
# Portfolio Manager options (value, text):
# INP000008464@@INP000008464@@1729 ADVISORS LLP -> 1729 ADVISORS LLP
# INP000005190@@INP000005190@@2POINT2 CAPITAL ADVISORS LLP -> 2POINT2 CAPITAL ADVISORS LLP
# INP000008640@@INP000008640@@360 ONE ALTERNATES ASSET MANAGEMENT LIMITED -> 360 ONE ALTERNATES ASSET MANAGEMENT LIMITED
# INP000004565@@INP000004565@@360 ONE ASSET MANAGEMENT LIMITED -> 360 ONE ASSET MANAGEMENT LIMITED
# INP000005874@@INP000005874@@360 ONE PORTFOLIO MANAGERS LIMITED -> 360 ONE PORTFOLIO MANAGERS LIMITED
# INP000006679@@INP000006679@@4A SECURITIES -> 4A SECURITIES
# INP000004730@@INP000004730@@A C CHOKSI SHARE BROKERS PRIVATE LIMITED -> A C CHOKSI SHARE BROKERS PRIVATE LIMITED
# INP000003674@@INP000003674@@A. K. WEALTH MANAGEMENT PRIVATE LIMITED -> A. K. WEALTH MANAGEMENT PRIVATE LIMITED
# INP000004599@@INP000004599@@AAROHAN HOLDINGS AND ADVISORS PRIVATE LIMITED -> AAROHAN HOLDINGS AND ADVISORS PRIVATE LIMITED
# INP000008224@@INP000008224@@AAVISHKAAR ADVISORS PRIVATE LIMITED -> AAVISHKAAR ADVISORS PRIVATE LIMITED
# INP000006457@@INP000006457@@ABAKKUS ASSET MANAGER LLP -> ABAKKUS ASSET MANAGER LLP
# INP000006484@@INP000006484@@ABANS BROKING SERVICES PRIVATE LIMITED -> ABANS BROKING SERVICES PRIVATE LIMITED
# INP000004904@@INP000004904@@ABCHLOR INVESTMENTS PRIVATE LIMITED -> ABCHLOR INVESTMENTS PRIVATE LIMITED
# INP000009010@@INP000009010@@ACCELT ASSET MANAGEMENT LLP -> ACCELT ASSET MANAGEMENT LLP
# INP000008844@@INP000008844@@ACCURACAP CONSULTANCY SERVICES PRIVATE LIMITED -> ACCURACAP CONSULTANCY SERVICES PRIVATE LIMITED
# INP000004037@@INP000004037@@ACCURACAP CONSULTANCY SERVICES PRIVATE LIMITED -> ACCURACAP CONSULTANCY SERVICES PRIVATE LIMITED
# INP000007492@@INP000007492@@ACE LANSDOWNE INVESTMENTS SERVICES LLP -> ACE LANSDOWNE INVESTMENTS SERVICES LLP
# INP000004854@@INP000004854@@ACEPRO ADVISORS PRIVATE LIMITED -> ACEPRO ADVISORS PRIVATE LIMITED
# INP000006350@@INP000006350@@ACHINTYA SECURITIES PRIVATE LIMITED -> ACHINTYA SECURITIES PRIVATE LIMITED
# INP000003757@@INP000003757@@ADITYA BIRLA MONEY LIMITED -> ADITYA BIRLA MONEY LIMITED
# INP000005349@@INP000005349@@ADROIT FINANCIAL SERVICES PRIVATE LIMITED -> ADROIT FINANCIAL SERVICES PRIVATE LIMITED
# INP000004417@@INP000004417@@AEQUITAS INVESTMENT CONSULTANCY PRIVATE LIMITED -> AEQUITAS INVESTMENT CONSULTANCY PRIVATE LIMITED
# INP000008321@@INP000008321@@AFFIRMA CAPITAL INVESTMENT ADVISER INDIA PRIVATE LIMITED -> AFFIRMA CAPITAL INVESTMENT ADVISER INDIA PRIVATE LIMITED
# INP000006077@@INP000006077@@AGREYA CAPITAL ADVISORS LLP -> AGREYA CAPITAL ADVISORS LLP
# INP000009296@@INP000009296@@AIALPHA FINANCIAL ADVISORY SERVICES PRIVATE LIMITED -> AIALPHA FINANCIAL ADVISORY SERVICES PRIVATE LIMITED
# INP000001363@@INP000001363@@ALANKIT ASSIGNMENTS LTD. -> ALANKIT ASSIGNMENTS LTD.
# INP000000365@@INP000000365@@ALCHEMY CAPITAL MANAGEMENT PRIVATE LTD -> ALCHEMY CAPITAL MANAGEMENT PRIVATE LTD
# INP000004771@@INP000004771@@ALDER CAPITAL ADVISORS LLP -> ALDER CAPITAL ADVISORS LLP
# INP000003419@@INP000003419@@ALFACCURATE ADVISORS PVT. LTD. -> ALFACCURATE ADVISORS PVT. LTD.
# INP000002437@@INP000002437@@ALLEGRO SECURITIES PRIVATE LIMITED -> ALLEGRO SECURITIES PRIVATE LIMITED
# INP000008589@@INP000008589@@ALMONDZ FINANCIAL SERVICES LIMITED -> ALMONDZ FINANCIAL SERVICES LIMITED
# INP000006518@@INP000006518@@ALPHA ALTERNATIVES FUND ADVISORS LLP -> ALPHA ALTERNATIVES FUND ADVISORS LLP
# INP000007401@@INP000007401@@ALPHAGREP INVESTMENT MANAGEMENT PRIVATE LIMITED -> ALPHAGREP INVESTMENT MANAGEMENT PRIVATE LIMITED
# INP000004698@@INP000004698@@ALTITUDE CAPITAL ADVISORS PRIVATE LIMITED -> ALTITUDE CAPITAL ADVISORS PRIVATE LIMITED
# INP000009126@@INP000009126@@AMALTAS ASSET MANAGEMENT LLP -> AMALTAS ASSET MANAGEMENT LLP
# INP000002221@@INP000002221@@AMBIT CAPITAL PRIVATE LTD -> AMBIT CAPITAL PRIVATE LTD
# INP000005059@@INP000005059@@AMBIT INVESTMENT ADVISORS PRIVATE LIMITED -> AMBIT INVESTMENT ADVISORS PRIVATE LIMITED
# INP000007465@@INP000007465@@AMBIT WEALTH PRIVATE LIMITED -> AMBIT WEALTH PRIVATE LIMITED
# INP000008941@@INP000008941@@AMICUS INDIA CAPITAL PARTNERS LLP  -> AMICUS INDIA CAPITAL PARTNERS LLP
# INP000006828@@INP000006828@@AMTIGER CONSULTANTS PRIVATE LIMITED -> AMTIGER CONSULTANTS PRIVATE LIMITED
# INP000000282@@INP000000282@@ANAND RATHI ADVISORS LIMITED -> ANAND RATHI ADVISORS LIMITED
# INP000009117@@INP000009117@@ANGEL ONE INVESTMENT MANAGERS  AND  ADVISORS PRIVATE LIMITED -> ANGEL ONE INVESTMENT MANAGERS  AND  ADVISORS PRIVATE LIMITED
# INP000001546@@INP000001546@@ANGEL ONE LIMITED -> ANGEL ONE LIMITED
# INP000009223@@INP000009223@@ANICUT CAPITAL LLP -> ANICUT CAPITAL LLP
# INP000004797@@INP000004797@@ANIVED PORTFOLIO MANAGERS PVT. LTD. -> ANIVED PORTFOLIO MANAGERS PVT. LTD.
# INP200007733@@INP200007733@@ANTLER INNOVATION INDIA PRIVATE LIMITED -> ANTLER INNOVATION INDIA PRIVATE LIMITED
# INP000002429@@INP000002429@@ANVIL WEALTH MANAGEMENT PVT LTD -> ANVIL WEALTH MANAGEMENT PVT LTD
# INP000009302@@INP000009302@@APRICUS WEALTH INVESTMENT MANAGERS LLP -> APRICUS WEALTH INVESTMENT MANAGERS LLP
# INP000006110@@INP000006110@@ARCH FINANCE LTD -> ARCH FINANCE LTD
# INP000009384@@INP000009384@@ARDEKO ASSET MANAGEMENT PRIVATE LIMITED -> ARDEKO ASSET MANAGEMENT PRIVATE LIMITED
# INP000008853@@INP000008853@@ARHAM WEALTH MANAGEMENT PRIVATE LIMITED -> ARHAM WEALTH MANAGEMENT PRIVATE LIMITED
# INP000006660@@INP000006660@@ARIHANT ASSET MANAGEMENT LIMITED -> ARIHANT ASSET MANAGEMENT LIMITED
# INP000008729@@INP000008729@@ARKA INVESTMENT ADVISORY SERVICES PRIVATE LIMITED -> ARKA INVESTMENT ADVISORY SERVICES PRIVATE LIMITED
# INP000008932@@INP000008932@@ARNYA REALESTATES FUND ADVISORS PRIVATE LIMITED -> ARNYA REALESTATES FUND ADVISORS PRIVATE LIMITED
# INP000008552@@INP000008552@@ARTH PORTFOLIO MANAGEMENT PRIVATE LIMITED -> ARTH PORTFOLIO MANAGEMENT PRIVATE LIMITED
# INP000009038@@INP000009038@@ARTHALPHA LLP -> ARTHALPHA LLP
# INP000007225@@INP000007225@@ARTHYA WEALTH AND INVESTMENTS PVT LTD -> ARTHYA WEALTH AND INVESTMENTS PVT LTD
# INP000009153@@INP000009153@@ASHIMA CAPITAL MANAGEMENT LIMITED -> ASHIMA CAPITAL MANAGEMENT LIMITED
# INP000004722@@INP000004722@@ASHLAR SECURITIES PVT. LTD. -> ASHLAR SECURITIES PVT. LTD.
# INP000004177@@INP000004177@@ASHWANI GUJRAL INVESTMENT & PORTFOLIO MANAGEMENT PVT. LTD. -> ASHWANI GUJRAL INVESTMENT & PORTFOLIO MANAGEMENT PVT. LTD.
# INP000004680@@INP000004680@@ASIAN MARKETS SECURITIES PRIVATE LIMITED -> ASIAN MARKETS SECURITIES PRIVATE LIMITED
# INP000005801@@INP000005801@@ASIT C. MEHTA INVESTMENT INTERRMEDIATES LIMITED -> ASIT C. MEHTA INVESTMENT INTERRMEDIATES LIMITED
# INP000008066@@INP000008066@@ASK INVESTMENT MANAGERS LIMITED -> ASK INVESTMENT MANAGERS LIMITED
# INP000000043@@INP000000043@@ASK INVESTMENT MANAGERS PRIVATE LIMITED -> ASK INVESTMENT MANAGERS PRIVATE LIMITED
# INP000005713@@INP000005713@@ASK PROPERTY INVESTMENT ADVISORS PRIVATE LIMITED -> ASK PROPERTY INVESTMENT ADVISORS PRIVATE LIMITED
# INP000007003@@INP000007003@@ASK WEALTH ADVISORS PRIVATE LIMITED -> ASK WEALTH ADVISORS PRIVATE LIMITED
# INP000007827@@INP000007827@@ASK WEALTH ADVISORS PRIVATE LIMITED -> ASK WEALTH ADVISORS PRIVATE LIMITED
# INP000002536@@INP000002536@@ASTUTE INVESTMENT MANAGEMENT PRIVATE LIMITED -> ASTUTE INVESTMENT MANAGEMENT PRIVATE LIMITED
# INP000009320@@INP000009320@@ATISHAY STOCK BROKING PRIVATE LIMITED -> ATISHAY STOCK BROKING PRIVATE LIMITED
# INP000000530@@INP000000530@@ATLAS INTEGRATED FINANCE LTD -> ATLAS INTEGRATED FINANCE LTD
# INP000006615@@INP000006615@@ATMAN CAPITAL MANAGEMENT PRIVATE LIMITED -> ATMAN CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000004805@@INP000004805@@ATS WEALTH MANAGERS PRIVATE LIMITED -> ATS WEALTH MANAGERS PRIVATE LIMITED
# INP000006217@@INP000006217@@AVENDUS CAPITAL PUBLIC MARKETS ALTERNATE STRATEGIES LLP -> AVENDUS CAPITAL PUBLIC MARKETS ALTERNATE STRATEGIES LLP
# INP000008774@@INP000008774@@AVENDUS PE INVESTMENT ADVISORS PRIVATE LIMITED -> AVENDUS PE INVESTMENT ADVISORS PRIVATE LIMITED
# INP000005257@@INP000005257@@AVENDUS WEALTH MANAGEMENT PRIVATE LTD -> AVENDUS WEALTH MANAGEMENT PRIVATE LTD
# INP000005810@@INP000005810@@AVESTHA FUND MANAGEMENT LLP -> AVESTHA FUND MANAGEMENT LLP
# INP000005406@@INP000005406@@AVEZO ADVISORS PRIVATE LIMITED -> AVEZO ADVISORS PRIVATE LIMITED
# INP000006934@@INP000006934@@AWRIGA CAPITAL ADVISORS LLP -> AWRIGA CAPITAL ADVISORS LLP
# INP000003534@@INP000003534@@AXIS ASSET MANAGEMENT COMPANY LIMITED -> AXIS ASSET MANAGEMENT COMPANY LIMITED
# INP000000654@@INP000000654@@AXIS SCEURITIES LIMITED -> AXIS SCEURITIES LIMITED
# INP000007614@@INP000007614@@AYAN ANALYTICS PRIVATE LIMITED -> AYAN ANALYTICS PRIVATE LIMITED
# INP000009135@@INP000009135@@B.N. RATHI SECURITIES LIMITED -> B.N. RATHI SECURITIES LIMITED
# INP000006527@@INP000006527@@BADJATE WEALTH PRIVATE LIMITED -> BADJATE WEALTH PRIVATE LIMITED
# INP000008534@@INP000008534@@BANDHAN AMC LIMITED -> BANDHAN AMC LIMITED
# INP000004243@@INP000004243@@BANYAN CAPITAL ADVISORS PRIVATE LIMITED -> BANYAN CAPITAL ADVISORS PRIVATE LIMITED
# INP000001173@@INP000001173@@BANYAN TREE ADVISORS PRIVATE LIMITED -> BANYAN TREE ADVISORS PRIVATE LIMITED
# INP000002585@@INP000002585@@BARCLAYS SECURITIES (INDIA) PRIVATE LIMITED -> BARCLAYS SECURITIES (INDIA) PRIVATE LIMITED
# INP000003716@@INP000003716@@BARODA BNP PARIBAS ASSET MANAGEMENT INDIA PRIVATE LIMITED -> BARODA BNP PARIBAS ASSET MANAGEMENT INDIA PRIVATE LIMITED
# INP000006262@@INP000006262@@BASAN EQUITY BROKING LIMITED -> BASAN EQUITY BROKING LIMITED
# INP000004946@@INP000004946@@BASANT MAHESHWARI WEALTH ADVISERS LLP -> BASANT MAHESHWARI WEALTH ADVISERS LLP
# INP000005208@@INP000005208@@BAY CAPITAL INVESTMENT ADVISORS PRIVATE LIMITED -> BAY CAPITAL INVESTMENT ADVISORS PRIVATE LIMITED
# INP000009199@@INP000009199@@BEAMS VC PARTNERZ LLP -> BEAMS VC PARTNERZ LLP
# INP000000910@@INP000000910@@BELLWETHER CAPITAL PRIVATE LIMITED -> BELLWETHER CAPITAL PRIVATE LIMITED
# INP000006411@@INP000006411@@BHANA EQUITY ADVISORS LLP -> BHANA EQUITY ADVISORS LLP
# INP000009162@@INP000009162@@BHARAT BHUSHAN EQUITY TRADERS LIMITED -> BHARAT BHUSHAN EQUITY TRADERS LIMITED
# INP000000597@@INP000000597@@BIRLA SUN LIFE ASSET MANAGEMENT COMPANY LIMITED -> BIRLA SUN LIFE ASSET MANAGEMENT COMPANY LIMITED
# INP000007553@@INP000007553@@BLACKSOIL ASSET MANAGEMENT PRIVATE LIMITED -> BLACKSOIL ASSET MANAGEMENT PRIVATE LIMITED
# INP000008747@@INP000008747@@BLUE 91 PORTFOLIO MANAGERS LLP -> BLUE 91 PORTFOLIO MANAGERS LLP
# INP000008057@@INP000008057@@BLUE ASHVA INDIA LLP -> BLUE ASHVA INDIA LLP
# INP000008783@@INP000008783@@BMC ADVISORS PRIVATE LIMITED -> BMC ADVISORS PRIVATE LIMITED
# INP000000985@@INP000000985@@BONANZA PORTFOLIO LIMITED -> BONANZA PORTFOLIO LIMITED
# INP000007119@@INP000007119@@BRAIN POINT INVESTMENT CENTRE PVT LTD -> BRAIN POINT INVESTMENT CENTRE PVT LTD
# INP000008996@@INP000008996@@BRIGHTSEEDS ADVISORS LLP -> BRIGHTSEEDS ADVISORS LLP
# INP000005430@@INP000005430@@BUGLEROCK CAPITAL PRIVATE LIMITED -> BUGLEROCK CAPITAL PRIVATE LIMITED
# INP000004425@@INP000004425@@BULLERO CAPITAL PRIVATE LIMITED -> BULLERO CAPITAL PRIVATE LIMITED
# INP000005000@@INP000005000@@BUOYANT CAPITAL PRIVATE LIMITED -> BUOYANT CAPITAL PRIVATE LIMITED
# INP100007091@@INP100007091@@BURMAN CAPITAL MANAGEMENT PRIVATE LIMITED -> BURMAN CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000008808@@INP000008808@@CACTUS PARTNERS LLP -> CACTUS PARTNERS LLP
# INP000003740@@INP000003740@@CANARA ROBECO ASSET MANAGEMENT COMPANY LIMITED -> CANARA ROBECO ASSET MANAGEMENT COMPANY LIMITED
# INP000006147@@INP000006147@@CAPGROW CAPITAL ADVISORS LLP -> CAPGROW CAPITAL ADVISORS LLP
# INP000008349@@INP000008349@@CAPITAL 8 LLP -> CAPITAL 8 LLP
# INP000005847@@INP000005847@@CAPITALMIND FINANCIAL SERVICES PRIVATE LIMITED -> CAPITALMIND FINANCIAL SERVICES PRIVATE LIMITED
# INP000001066@@INP000001066@@CAPSTOCKS AND SECURITIES (INDIA) PRIVATE -> CAPSTOCKS AND SECURITIES (INDIA) PRIVATE
# INP000004128@@INP000004128@@CARE PORTFOLIO MANAGERS PRIVATE LIMITED -> CARE PORTFOLIO MANAGERS PRIVATE LIMITED
# INP000006387@@INP000006387@@CARNELIAN ASSET MANAGEMENT  AND  ADVISORS PRIVATE LIMITED -> CARNELIAN ASSET MANAGEMENT  AND  ADVISORS PRIVATE LIMITED
# INP000008358@@INP000008358@@CASPIAN IMPACT INVESTMENT ADVISER PRIVATE LIMITED -> CASPIAN IMPACT INVESTMENT ADVISER PRIVATE LIMITED
# INP000006004@@INP000006004@@CATALYTIC SOLUTION AND MANAGEMENT SERVICES PRIVATE LIMITED -> CATALYTIC SOLUTION AND MANAGEMENT SERVICES PRIVATE LIMITED
# INP000005917@@INP000005917@@CENTRUM ALTERNATIVES LLP -> CENTRUM ALTERNATIVES LLP
# INP000004383@@INP000004383@@CENTRUM BROKING LIMITED -> CENTRUM BROKING LIMITED
# INP000007535@@INP000007535@@CENTRUM INVESTMENT ADVISORS LIMITED -> CENTRUM INVESTMENT ADVISORS LIMITED
# INP000006040@@INP000006040@@CHANAKYA CAPITAL SERVICES PRIVATE LIMITED -> CHANAKYA CAPITAL SERVICES PRIVATE LIMITED
# INP000005856@@INP000005856@@CHOICE PORTFOLIO MANAGEMENT SERVICES PRIVATE LIMITED.  -> CHOICE PORTFOLIO MANAGEMENT SERVICES PRIVATE LIMITED.
# INP000001199@@INP000001199@@CHONA FINANCIAL SERVICES LTD -> CHONA FINANCIAL SERVICES LTD
# INP000009241@@INP000009241@@CHRYSCAPITAL ADVISORS LLP -> CHRYSCAPITAL ADVISORS LLP
# INP000008206@@INP000008206@@CITRUS ADVISORS PRIVATE LIMITED -> CITRUS ADVISORS PRIVATE LIMITED
# INP000007164@@INP000007164@@CKREDENCE WEALTH MANAGEMENT PRIVATE LIMITED -> CKREDENCE WEALTH MANAGEMENT PRIVATE LIMITED
# INP000009029@@INP000009029@@CLEARVIEW CAPITAL ADVISORS PRIVATE LIMITED -> CLEARVIEW CAPITAL ADVISORS PRIVATE LIMITED
# INP000008473@@INP000008473@@CLOCKVINE CAPITAL ADVISORS PVT LTD -> CLOCKVINE CAPITAL ADVISORS PVT LTD
# INP000005380@@INP000005380@@CLUBMILLIONAIRE FINANCIAL SERVICES PRIVATE LIMITED -> CLUBMILLIONAIRE FINANCIAL SERVICES PRIVATE LIMITED
# INP100007365@@INP100007365@@COMPLETE CIRCLEWEALTH SOLUTIONS LLP  -> COMPLETE CIRCLEWEALTH SOLUTIONS LLP
# INP000006396@@INP000006396@@COMPOSITE INVESTMENTS PRIVATE LIMITED -> COMPOSITE INVESTMENTS PRIVATE LIMITED
# INP000006633@@INP000006633@@COMPOUND EVERYDAY CAPITAL MANAGEMENT LLP -> COMPOUND EVERYDAY CAPITAL MANAGEMENT LLP
# INP000006323@@INP000006323@@CONCEPT INVESTWELL PRIVATE LIMITED   -> CONCEPT INVESTWELL PRIVATE LIMITED
# INP000003658@@INP000003658@@CONSORTIUM SECURITIES PVT. LTD. -> CONSORTIUM SECURITIES PVT. LTD.
# INP000008710@@INP000008710@@CONSTELLATION SPORTS  AND  ENTERTAINMENT PARTNERS LLP -> CONSTELLATION SPORTS  AND  ENTERTAINMENT PARTNERS LLP
# INP000006305@@INP000006305@@CORESTRAT HERAMB LLP -> CORESTRAT HERAMB LLP
# INP100007620@@INP100007620@@CORNUCOPIA CONSUMER VENTURE ADVISORY LLP -> CORNUCOPIA CONSUMER VENTURE ADVISORY LLP
# INP000008190@@INP000008190@@CORPORATE BUSINESS ADVISORS PRIVATE LIMITED -> CORPORATE BUSINESS ADVISORS PRIVATE LIMITED
# INP000006554@@INP000006554@@COUNTER CYCLICAL INVESTMENTS PRIVATE LIMITED -> COUNTER CYCLICAL INVESTMENTS PRIVATE LIMITED
# INP000008303@@INP000008303@@COURSER PARK ADVISORS LLP -> COURSER PARK ADVISORS LLP
# INP000006101@@INP000006101@@CREDENT ASSET MANAGEMENT SERVICES PRIVATE LIMITED -> CREDENT ASSET MANAGEMENT SERVICES PRIVATE LIMITED
# INP000002478@@INP000002478@@CREDIT SUISSE SECURITIES INDIA PRIVATE LIMITED -> CREDIT SUISSE SECURITIES INDIA PRIVATE LIMITED
# INP000005026@@INP000005026@@CRESCITA INVESTMENT MANAGEMENT PRIVATE LIMITED -> CRESCITA INVESTMENT MANAGEMENT PRIVATE LIMITED
# INP000009214@@INP000009214@@CUMULUS ADVISORY LLP -> CUMULUS ADVISORY LLP
# INP000008525@@INP000008525@@CX ADVISORS LLP -> CX ADVISORS LLP
# INP000003997@@INP000003997@@DAIWA ASSET MANAGEMENT (INDIA) PRIVATE LIMITED -> DAIWA ASSET MANAGEMENT (INDIA) PRIVATE LIMITED
# INP000001975@@INP000001975@@DALAL  AND  BROACHA STOCK BROKING PVT. LTD. -> DALAL  AND  BROACHA STOCK BROKING PVT. LTD.
# INP000000431@@INP000000431@@DARASHAW  AND  COMPANY LTD -> DARASHAW  AND  COMPANY LTD
# INP000006013@@INP000006013@@DECIMAL WEALTH PARTNERS PVT LTD -> DECIMAL WEALTH PARTNERS PVT LTD
# INP000002825@@INP000002825@@DEUTSCHE INVESTMENTS INDIA PRIVATE LIMITED -> DEUTSCHE INVESTMENTS INDIA PRIVATE LIMITED
# INP000007377@@INP000007377@@DEZERV INVESTMENTS PRIVATE LIMITED -> DEZERV INVESTMENTS PRIVATE LIMITED
# INP000004870@@INP000004870@@DGS CAPITAL MANAGEMENT PRIVATE LIMITED -> DGS CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000008145@@INP000008145@@DIVYA CAPITAL ONE PRIVATE LIMITED -> DIVYA CAPITAL ONE PRIVATE LIMITED
# INP000005944@@INP000005944@@DMZ PARTNERS INVESTMENT MANAGEMENT LLP -> DMZ PARTNERS INVESTMENT MANAGEMENT LLP
# INP000003302@@INP000003302@@DOHA BROKERAGE AND FINANCIAL SERVICES LTD -> DOHA BROKERAGE AND FINANCIAL SERVICES LTD
# INP000007906@@INP000007906@@DRCHOKSEY FINSERV PRIVATE LIMITED -> DRCHOKSEY FINSERV PRIVATE LIMITED
# INP000008570@@INP000008570@@DRIV DRISHT LLP -> DRIV DRISHT LLP
# INP000008561@@INP000008561@@DWAITH ADVISORY PRIVATE LIMITED -> DWAITH ADVISORY PRIVATE LIMITED
# INP000003468@@INP000003468@@DYNAMIC EQUITIES PRIVATE LIMITED -> DYNAMIC EQUITIES PRIVATE LIMITED
# INP000008075@@INP000008075@@EAST GREEN ADVISORS LLP -> EAST GREEN ADVISORS LLP
# INP000007058@@INP000007058@@EAST LANE CAPITAL LLP  -> EAST LANE CAPITAL LLP
# INP000009250@@INP000009250@@EBISU INVESTMENT ADVISORS LLP -> EBISU INVESTMENT ADVISORS LLP
# INP000008260@@INP000008260@@EDELWEISS ALTERNATIVE ASSET ADVISORS LIMITED -> EDELWEISS ALTERNATIVE ASSET ADVISORS LIMITED
# INP000004631@@INP000004631@@EDELWEISS ASSET MANAGEMENT LIMITED -> EDELWEISS ASSET MANAGEMENT LIMITED
# INP000008880@@INP000008880@@EDELWEISS GLOBAL WEALTH MANAGEMENT LIMITED -> EDELWEISS GLOBAL WEALTH MANAGEMENT LIMITED
# INP000007243@@INP000007243@@EDHA WEALTH LLP -> EDHA WEALTH LLP
# INP000005265@@INP000005265@@EKLAVYA CAPITAL ADVISORS LLP -> EKLAVYA CAPITAL ADVISORS LLP
# INP000007544@@INP000007544@@ELECTRUM PORTFOLIO MANAGERS PRIVATE LIMITED -> ELECTRUM PORTFOLIO MANAGERS PRIVATE LIMITED
# INP000008905@@INP000008905@@ELEVER INVESTMENT ADVISER PRIVATE LIMITED -> ELEVER INVESTMENT ADVISER PRIVATE LIMITED
# INP000003021@@INP000003021@@ELITE WEALTH LIMITED -> ELITE WEALTH LIMITED
# INP000002163@@INP000002163@@ELIXIR EQUITIES PVT. LTD. -> ELIXIR EQUITIES PVT. LTD.
# INP000004755@@INP000004755@@ELYSIUM INVESTMENT ADVISORS LLP -> ELYSIUM INVESTMENT ADVISORS LLP
# INP000004458@@INP000004458@@EMKAY INVESTMENT MANAGERS LIMITED -> EMKAY INVESTMENT MANAGERS LIMITED
# INP000000225@@INP000000225@@ENAM ASSET MANAGEMENT CO.PVT.LTD -> ENAM ASSET MANAGEMENT CO.PVT.LTD
# INP000006314@@INP000006314@@ENTRUST FAMILY OFFICE INVESTMENT ADVISORS PRIVATE LIMITED -> ENTRUST FAMILY OFFICE INVESTMENT ADVISORS PRIVATE LIMITED
# INP000003575@@INP000003575@@ENVISION CAPITAL SERVICES PVT.LTD. -> ENVISION CAPITAL SERVICES PVT.LTD.
# INP000007793@@INP000007793@@EPIQ CAPITAL INVESTMENT ADVISORY LLP -> EPIQ CAPITAL INVESTMENT ADVISORY LLP
# INP000007580@@INP000007580@@EQUANIMITY MANAGEMENT SERVICES LLP -> EQUANIMITY MANAGEMENT SERVICES LLP
# INP000008969@@INP000008969@@EQUENTIS WEALTH ADVISORY SERVICES LIMITED -> EQUENTIS WEALTH ADVISORY SERVICES LIMITED
# INP000006208@@INP000006208@@EQUINOMICS RESEARCH & ADVISORY PRIVATE LIMITED -> EQUINOMICS RESEARCH & ADVISORY PRIVATE LIMITED
# INP000008756@@INP000008756@@EQUIPOISE CAPITAL MANAGEMENT PRIVATE LIMITED -> EQUIPOISE CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000005216@@INP000005216@@EQUIRUS SECURITIES PRIVATE LIMITED -> EQUIRUS SECURITIES PRIVATE LIMITED
# INP000007076@@INP000007076@@EQUIRUS WEALTH PRIVATE LIMITED -> EQUIRUS WEALTH PRIVATE LIMITED
# INP000005777@@INP000005777@@EQUITREE CAPITAL ADVISORS PRIVATE LIMITED -> EQUITREE CAPITAL ADVISORS PRIVATE LIMITED
# INP000000787@@INP000000787@@EQUITY INTELLIGENCE INDIA PVT. LTD. -> EQUITY INTELLIGENCE INDIA PVT. LTD.
# INP000005372@@INP000005372@@ESCORP ASSET MANAGEMENT LIMITED -> ESCORP ASSET MANAGEMENT LIMITED
# INP000001454@@INP000001454@@ESCORTS SECURITIES LIMITED -> ESCORTS SECURITIES LIMITED
# INP000007720@@INP000007720@@ESTEE ADVISORS PRIVATE LIMITED -> ESTEE ADVISORS PRIVATE LIMITED
# INP000003146@@INP000003146@@ESTEE ADVISORS PVT LTD. -> ESTEE ADVISORS PVT LTD.
# INP000005740@@INP000005740@@EUREKA PORTFOLIO MANAGEMENT SERVICES PVT LTD -> EUREKA PORTFOLIO MANAGEMENT SERVICES PVT LTD
# INP000009269@@INP000009269@@FE SECURITIES PRIVATE LIMITED -> FE SECURITIES PRIVATE LIMITED
# INP000008482@@INP000008482@@FIDENT ASSET MANAGEMENT PRIVATE LIMITED -> FIDENT ASSET MANAGEMENT PRIVATE LIMITED
# INP000008668@@INP000008668@@FINCOS TECHNOLOGY SOLUTIONS PRIVATE LIMITED -> FINCOS TECHNOLOGY SOLUTIONS PRIVATE LIMITED
# INP000009056@@INP000009056@@FINDOC INVESTMART PRIVATE LIMITED -> FINDOC INVESTMART PRIVATE LIMITED
# INP000008950@@INP000008950@@FINWIZARD TECHNOLOGY PRIVATE LIMITED -> FINWIZARD TECHNOLOGY PRIVATE LIMITED
# INP200007441@@INP200007441@@FIRESIDE INVESTMENT ADVISORY LLP  -> FIRESIDE INVESTMENT ADVISORY LLP
# INP200007690@@INP200007690@@FIRESIDE VENTURES ADVISORY LLP  -> FIRESIDE VENTURES ADVISORY LLP
# INP000008367@@INP000008367@@FIRST BRIDGE INVESTMENT MANAGERS PRIVATE LIMITED -> FIRST BRIDGE INVESTMENT MANAGERS PRIVATE LIMITED
# INP000006697@@INP000006697@@FIRST GLOBAL FINANCE PVT LTD -> FIRST GLOBAL FINANCE PVT LTD
# INP000009205@@INP000009205@@FIRSTPORT GROWTH VENTURES LLP -> FIRSTPORT GROWTH VENTURES LLP
# INP000008491@@INP000008491@@FIRSTPORT VENTURES LLP -> FIRSTPORT VENTURES LLP
# INP000009278@@INP000009278@@FISCALEYE PRIVATE LIMITED -> FISCALEYE PRIVATE LIMITED
# INP000004474@@INP000004474@@FIVE RIVERS PORTFOLIO MANAGERS PRIVATE LIMITED -> FIVE RIVERS PORTFOLIO MANAGERS PRIVATE LIMITED
# INP000006031@@INP000006031@@FORT CAPITAL INVESTMENT ADVISORY PRIVATE LIMITED -> FORT CAPITAL INVESTMENT ADVISORY PRIVATE LIMITED
# INP000008093@@INP000008093@@FORTUNA INVESTMENT ADVISORS LLP -> FORTUNA INVESTMENT ADVISORS LLP
# INP000008622@@INP000008622@@FORTUNE WEALTH MANAGEMENT COMPANY INDIA PRIVATE LIMITED -> FORTUNE WEALTH MANAGEMENT COMPANY INDIA PRIVATE LIMITED
# INP000008084@@INP000008084@@FOUR DIMENSIONS ADVISORS PRIVATE LIMITED -> FOUR DIMENSIONS ADVISORS PRIVATE LIMITED
# INP000007146@@INP000007146@@FRACTAL CAPITAL INVESTMENTS LLP -> FRACTAL CAPITAL INVESTMENTS LLP
# INP000000464@@INP000000464@@FRANKLIN TEMPLETON ASSET MANAGEMENT (INDIA) PRIVATE LIMITED -> FRANKLIN TEMPLETON ASSET MANAGEMENT (INDIA) PRIVATE LIMITED
# INP000008172@@INP000008172@@FUNDAMENTUM INVESTMENT ADVISORS LLP -> FUNDAMENTUM INVESTMENT ADVISORS LLP
# INP000008659@@INP000008659@@FYERS ASSET MANAGEMENT PRIVATE LIMITED -> FYERS ASSET MANAGEMENT PRIVATE LIMITED
# INP000008154@@INP000008154@@GAJA ALTERNATIVE ASSET MANAGEMENT PRIVATE LIMITED -> GAJA ALTERNATIVE ASSET MANAGEMENT PRIVATE LIMITED
# INP000009287@@INP000009287@@GEMS IMPERIAL PORTFOLIO ADVISORY LLP -> GEMS IMPERIAL PORTFOLIO ADVISORY LLP
# INP000003203@@INP000003203@@GEOJIT FINANCIAL SERVICES LIMITED -> GEOJIT FINANCIAL SERVICES LIMITED
# INP000004334@@INP000004334@@GHALLA BHANSALI STOCK BROKERS PRIVATE LIMITED -> GHALLA BHANSALI STOCK BROKERS PRIVATE LIMITED
# INP000003369@@INP000003369@@GIRIK WEALTH ADVISORS PRIVATE LIMITED -> GIRIK WEALTH ADVISORS PRIVATE LIMITED
# INP000006493@@INP000006493@@GLOBALWORTH SECURITIES LIMITED -> GLOBALWORTH SECURITIES LIMITED
# INP000002361@@INP000002361@@GLOBE CAPITAL MARKET LTD. -> GLOBE CAPITAL MARKET LTD.
# INP000005999@@INP000005999@@GOCAPITAL FINANCE LIMITED -> GOCAPITAL FINANCE LIMITED
# INP000007687@@INP000007687@@GOLDMAN SACHS ASSET MANAGEMENT (INDIA) PRIVATE LIMITED -> GOLDMAN SACHS ASSET MANAGEMENT (INDIA) PRIVATE LIMITED
# INP000009171@@INP000009171@@GOLDSTANDARD WEALTH PRIVATE LIMITED -> GOLDSTANDARD WEALTH PRIVATE LIMITED
# INP200007195@@INP200007195@@GOOD FORTUNE CAPITALS PRIVATE LIMITED -> GOOD FORTUNE CAPITALS PRIVATE LIMITED
# INP000005829@@INP000005829@@GREEN LANTERN CAPITAL LLP -> GREEN LANTERN CAPITAL LLP
# INP000006022@@INP000006022@@GREEN PORTFOLIO PRIVATE LIMITED -> GREEN PORTFOLIO PRIVATE LIMITED
# INP000006837@@INP000006837@@GROVALUE FINANCIAL SERVICES PRIVATE LIMITED -> GROVALUE FINANCIAL SERVICES PRIVATE LIMITED
# INP000009418@@INP000009418@@GROWTHFINITI WEALTH PRIVATE LIMITED -> GROWTHFINITI WEALTH PRIVATE LIMITED
# INP000009065@@INP000009065@@GROWW WEALTH MANAGEMENT PRIVATE LIMITED -> GROWW WEALTH MANAGEMENT PRIVATE LIMITED
# INP000001983@@INP000001983@@GUARDIAN ADVISORS PVT LTD -> GUARDIAN ADVISORS PVT LTD
# INP000001819@@INP000001819@@GUARDIAN ADVISORS PVT LTD -> GUARDIAN ADVISORS PVT LTD
# INP000006563@@INP000006563@@GUARDIAN ASSET MANAGEMENT PRIVATE LIMITED -> GUARDIAN ASSET MANAGEMENT PRIVATE LIMITED
# INP000006439@@INP000006439@@HANUT ALTERNATE INVESTMENTS LLP -> HANUT ALTERNATE INVESTMENTS LLP
# INP000003898@@INP000003898@@HARMONEY FINSERV INDIA PRIVATE LIMITED -> HARMONEY FINSERV INDIA PRIVATE LIMITED
# INP000000506@@INP000000506@@HDFC ASSET MANAGEMENT COMPANY LIMITED -> HDFC ASSET MANAGEMENT COMPANY LIMITED
# INP000007784@@INP000007784@@HDFC CAPITAL ADVISORS LIMITED -> HDFC CAPITAL ADVISORS LIMITED
# INP000003476@@INP000003476@@HEDGE EQUITIES LTD -> HEDGE EQUITIES LTD
# INP000006916@@INP000006916@@HELIOS CAPITAL ASSET MANAGEMENT (INDIA) PRIVATE LIMITED -> HELIOS CAPITAL ASSET MANAGEMENT (INDIA) PRIVATE LIMITED
# INP000006794@@INP000006794@@HEM SECURITIES LIMITED -> HEM SECURITIES LIMITED
# INP200007672@@INP200007672@@HIMALAYA INVESTMENT ADVISORS LLP -> HIMALAYA INVESTMENT ADVISORS LLP
# INP000007517@@INP000007517@@HPMG SHARES AND SECURITIES PRIVATE LIMITED -> HPMG SHARES AND SECURITIES PRIVATE LIMITED
# INP000001322@@INP000001322@@HSBC ASSET MANAGEMENT (INDIA) PVT. LTD. -> HSBC ASSET MANAGEMENT (INDIA) PVT. LTD.
# INP000005908@@INP000005908@@HUNTER WEALTH MANAGEMENT LLP -> HUNTER WEALTH MANAGEMENT LLP
# INP000000373@@INP000000373@@ICICI PRUDENTIAL ASSET MANAGEMENT COMPANY LTD. -> ICICI PRUDENTIAL ASSET MANAGEMENT COMPANY LTD.
# INP000004060@@INP000004060@@ICICI SECURITIES LIMITED -> ICICI SECURITIES LIMITED
# INP000000696@@INP000000696@@ICICI SECURITIES PRIMARY DEALERSHIP LTD. -> ICICI SECURITIES PRIMARY DEALERSHIP LTD.
# INP000008604@@INP000008604@@ICICI VENTURE FUNDS MANAGEMENT COMPANY LIMITED -> ICICI VENTURE FUNDS MANAGEMENT COMPANY LIMITED
# INP000000209@@INP000000209@@IDBI CAPITAL MARKET SERVICES LTD -> IDBI CAPITAL MARKET SERVICES LTD
# INP000002064@@INP000002064@@IDFC ASSET MANAGEMENT COMPANY LIMITED -> IDFC ASSET MANAGEMENT COMPANY LIMITED
# INP000002213@@INP000002213@@IIFL CAPITAL SERVICES LIMITED -> IIFL CAPITAL SERVICES LIMITED
# INP000006651@@INP000006651@@IIFL WEALTH ADVISORS INDIA LIMITED -> IIFL WEALTH ADVISORS INDIA LIMITED
# INP000002676@@INP000002676@@IIFL WEALTH MANAGEMENT LIMITED -> IIFL WEALTH MANAGEMENT LIMITED
# INP000009232@@INP000009232@@IKIGAI ASSET MANAGER HOLDINGS PRIVATE LIMITED -> IKIGAI ASSET MANAGER HOLDINGS PRIVATE LIMITED
# INP000003237@@INP000003237@@IL AND FS INVESTMENT MANAGERS LIMITED -> IL AND FS INVESTMENT MANAGERS LIMITED
# INP000002130@@INP000002130@@IMPETUS ARTHASUTRA PRIVATE LIMITED -> IMPETUS ARTHASUTRA PRIVATE LIMITED
# INP000007410@@INP000007410@@INCRED ASSET MANAGEMENT PRIVATE LIMITED -> INCRED ASSET MANAGEMENT PRIVATE LIMITED
# INP000007128@@INP000007128@@INCRED CAPITAL WEALTH PORTFOLIO MANAGERS PRIVATE LIMITED -> INCRED CAPITAL WEALTH PORTFOLIO MANAGERS PRIVATE LIMITED
# INP000006606@@INP000006606@@INDGROWTH CAPITAL ADVISORS LLP -> INDGROWTH CAPITAL ADVISORS LLP
# INP000004938@@INP000004938@@INDIABULLS ASSET MANAGEMENT CO. LTD. -> INDIABULLS ASSET MANAGEMENT CO. LTD.
# INP100007709@@INP100007709@@INDIABULLS INVESTMENT MANAGEMENT LIMITED -> INDIABULLS INVESTMENT MANAGEMENT LIMITED
# INP000008385@@INP000008385@@INDIAN ANGEL NETWORK SERVICES PRIVATE LIMITED -> INDIAN ANGEL NETWORK SERVICES PRIVATE LIMITED
# INP000001892@@INP000001892@@INDSEC SECURITIES AND FINANCE LTD. -> INDSEC SECURITIES AND FINANCE LTD.
# INP000004813@@INP000004813@@INFINITY ALTERNATIVES INVESTMENT MANAGERS PRIVATE LIMITED -> INFINITY ALTERNATIVES INVESTMENT MANAGERS PRIVATE LIMITED
# INP000008695@@INP000008695@@INSIGHTFUL INVESTMENT MANAGER LLP -> INSIGHTFUL INVESTMENT MANAGER LLP
# INP000008039@@INP000008039@@INTEGROW ASSET MANAGEMENT PRIVATE LIMITED -> INTEGROW ASSET MANAGEMENT PRIVATE LIMITED
# INP000006907@@INP000006907@@INVASSET LLP -> INVASSET LLP
# INP000005273@@INP000005273@@INVESCO ASSET MANAGEMENT (INDIA) PRIVATE LIMITED -> INVESCO ASSET MANAGEMENT (INDIA) PRIVATE LIMITED
# INP000008507@@INP000008507@@INVESQ INVESTMENT MANAGERS LLP -> INVESQ INVESTMENT MANAGERS LLP
# INP000007632@@INP000007632@@INVESTCORP INDIA ASSET MANAGERS PRIVATE LIMITED -> INVESTCORP INDIA ASSET MANAGERS PRIVATE LIMITED
# INP000007395@@INP000007395@@INVESTSAVVY PORTFOLIO MANAGEMENT LLP -> INVESTSAVVY PORTFOLIO MANAGEMENT LLP
# INP000007137@@INP000007137@@INVEXA CAPITAL LLP -> INVEXA CAPITAL LLP
# INP000009339@@INP000009339@@INVICTA CAPSERV PRIVATE LIMITED -> INVICTA CAPSERV PRIVATE LIMITED
# INP000009074@@INP000009074@@IRONCLAD ASSET MANAGEMENT LLP -> IRONCLAD ASSET MANAGEMENT LLP
# INP000006448@@INP000006448@@ITHOUGHT FINANCIAL CONSULTING LLP -> ITHOUGHT FINANCIAL CONSULTING LLP
# INP000006402@@INP000006402@@ITI ALTERNATE FUNDS MANAGEMENT LIMITED -> ITI ALTERNATE FUNDS MANAGEMENT LIMITED
# INP000006341@@INP000006341@@ITUS CAPITAL ADVISORS PVT LTD -> ITUS CAPITAL ADVISORS PVT LTD
# INP000008826@@INP000008826@@IVYCAP VENTURES ADVISORS PRIVATE LIMITED -> IVYCAP VENTURES ADVISORS PRIVATE LIMITED
# INP000004979@@INP000004979@@JAIN INVESTMENT ADVISORS PVT. LTD -> JAIN INVESTMENT ADVISORS PVT. LTD
# INP000006785@@INP000006785@@JAINAM BROKING LIMITED -> JAINAM BROKING LIMITED
# INP000007881@@INP000007881@@JAMA WEALTH ASSET MANAGEMENT PRIVATE LIMITED -> JAMA WEALTH ASSET MANAGEMENT PRIVATE LIMITED
# INP000001215@@INP000001215@@JANAK MERCHANT SECURITIES PVT LTD -> JANAK MERCHANT SECURITIES PVT LTD
# INP000008297@@INP000008297@@JASHVIK CAPITAL ADVISORY LLP -> JASHVIK CAPITAL ADVISORY LLP
# INP000000993@@INP000000993@@JEETAY INVESTMENTS PVT LTD -> JEETAY INVESTMENTS PVT LTD
# INP000002759@@INP000002759@@JM FINANCIAL ASSET MANAGEMENT LTD. -> JM FINANCIAL ASSET MANAGEMENT LTD.
# INP000008455@@INP000008455@@JM FINANCIAL LIMITED -> JM FINANCIAL LIMITED
# INP000000621@@INP000000621@@JM FINANCIAL SERVICES  LTD -> JM FINANCIAL SERVICES  LTD
# INP000006138@@INP000006138@@JOINDRE CAPITAL SERVICES LIMITED -> JOINDRE CAPITAL SERVICES LIMITED
# INP000007012@@INP000007012@@JULIUS BAER WEALTH ADVISORS INDIA PRIVATE LIMITED -> JULIUS BAER WEALTH ADVISORS INDIA PRIVATE LIMITED
# INP000007863@@INP000007863@@KAE CAPITAL MANAGEMENT PRIVATE LIMITED -> KAE CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000008394@@INP000008394@@KAPM VENTURES LLP -> KAPM VENTURES LLP
# INP000001223@@INP000001223@@KARMA CAPITAL ADVISORS PVT. LTD. -> KARMA CAPITAL ADVISORS PVT. LTD.
# INP000004524@@INP000004524@@KARVY CAPITAL LIMITED -> KARVY CAPITAL LIMITED
# INP000001512@@INP000001512@@KARVY STOCK BROKING LTD. -> KARVY STOCK BROKING LTD.
# INP000001041@@INP000001041@@KB CAPITAL MARKETS PVT. LTD. -> KB CAPITAL MARKETS PVT. LTD.
# INP000006590@@INP000006590@@KEDIA SHARES  AND  STOCKS BROKERS LTD -> KEDIA SHARES  AND  STOCKS BROKERS LTD
# INP000000340@@INP000000340@@KHANDWALA SECURITIES LTD -> KHANDWALA SECURITIES LTD
# INP000006280@@INP000006280@@KLAY SECURITIES PRIVATE LIMITED -> KLAY SECURITIES PRIVATE LIMITED
# INP000004987@@INP000004987@@KOTAK ALTERNATE ASSET MANAGERS LIMITED -> KOTAK ALTERNATE ASSET MANAGERS LIMITED
# INP000000837@@INP000000837@@KOTAK MAHINDRA ASSET MANAGEMENT COMPANY LTD -> KOTAK MAHINDRA ASSET MANAGEMENT COMPANY LTD
# INP000000258@@INP000000258@@KOTAK SECURITIES LTD -> KOTAK SECURITIES LTD
# INP000001124@@INP000001124@@KRCHOKSEY SHARES AND SECURITIES PRIVATE LIMITED -> KRCHOKSEY SHARES AND SECURITIES PRIVATE LIMITED
# INP000006545@@INP000006545@@KRIIS PORTFOLIO PVT. LTD. -> KRIIS PORTFOLIO PVT. LTD.
# INP000006299@@INP000006299@@KSEMA WEALTH PVT LTD -> KSEMA WEALTH PVT LTD
# INP000004540@@INP000004540@@KUNVARJI FINSTOCK PRIVATE LIMITED -> KUNVARJI FINSTOCK PRIVATE LIMITED
# INP000008312@@INP000008312@@KYNG CAPITAL MANAGEMENT PRIVATE LIMITED -> KYNG CAPITAL MANAGEMENT PRIVATE LIMITED
# INP000003682@@INP000003682@@L&T INVESTMENT MANAGEMENT LIMITED -> L&T INVESTMENT MANAGEMENT LIMITED
# INP000003526@@INP000003526@@LABURNUM CAPITAL ADVISORS PRIVATE LIMITED -> LABURNUM CAPITAL ADVISORS PRIVATE LIMITED
# INP000007775@@INP000007775@@LADDERUP WEALTH MANAGEMENT PVT LTD  -> LADDERUP WEALTH MANAGEMENT PVT LTD
# INP000006767@@INP000006767@@LAKEWATER ADVISORS PRIVATE LIMITED -> LAKEWATER ADVISORS PRIVATE LIMITED
# INP000006378@@INP000006378@@LAPIS INDIA CAPITAL ADVISORS PRIVATE LIMITED -> LAPIS INDIA CAPITAL ADVISORS PRIVATE LIMITED
# INP000008437@@INP000008437@@LATENT ADVISORS LLP -> LATENT ADVISORS LLP
# INP000008792@@INP000008792@@LAUREL SECURITIES PRIVATE LIMITED -> LAUREL SECURITIES PRIVATE LIMITED
# INP000008163@@INP000008163@@LC CAPITAL INDIA PRIVATE LIMITED -> LC CAPITAL INDIA PRIVATE LIMITED
# INP200007432@@INP200007432@@LC NUEVA INVESTMENT PARTNERS LLP -> LC NUEVA INVESTMENT PARTNERS LLP
# INP000009180@@INP000009180@@LCATTERTON MUMBAI ADVISORY SERVICES PRIVATE LIMITED -> LCATTERTON MUMBAI ADVISORY SERVICES PRIVATE LIMITED
# INP000006721@@INP000006721@@LFS BROKING PRIVATE LIMITED -> LFS BROKING PRIVATE LIMITED
# INP000008376@@INP000008376@@LGT WEALTH INDIA PRIVATE LIMITED -> LGT WEALTH INDIA PRIVATE LIMITED
# INP000007322@@INP000007322@@LGT WEALTH INDIA PRIVATE LIMITED -> LGT WEALTH INDIA PRIVATE LIMITED
# INP000008419@@INP000008419@@LIBORD BROKERAGE PRIVATE LIMITED -> LIBORD BROKERAGE PRIVATE LIMITED
# INP000001694@@INP000001694@@LIC MUTUAL FUND ASSET MANAGEMENT LTD -> LIC MUTUAL FUND ASSET MANAGEMENT LTD
# INP000008215@@INP000008215@@LIGHTHOUSE AMC PRIVATE LIMITED -> LIGHTHOUSE AMC PRIVATE LIMITED
# INP000005299@@INP000005299@@LKP SECURITIES LTD -> LKP SECURITIES LTD
# INP000006688@@INP000006688@@LOGICTREE INVESTMENT ADVISERS PRIVATE LIMITED -> LOGICTREE INVESTMENT ADVISERS PRIVATE LIMITED
# INP000004953@@INP000004953@@M/S JHP SECURITIES PRIVATE LIMITED -> M/S JHP SECURITIES PRIVATE LIMITED
# INP000006536@@INP000006536@@M/S.ASTEYA INVESTMENT MANAGERS LLP, -> M/S.ASTEYA INVESTMENT MANAGERS LLP,
# INP000007155@@INP000007155@@MAGADH CAPITAL ADVISORS LLP -> MAGADH CAPITAL ADVISORS LLP
# INP000006581@@INP000006581@@MANGAL KESHAV SECURITIES LIMITED -> MANGAL KESHAV SECURITIES LIMITED
# INP000007605@@INP000007605@@MANSI SHARE  AND  STOCK ADVISORS PRIVATE LIMITED  -> MANSI SHARE  AND  STOCK ADVISORS PRIVATE LIMITED
# INP000005722@@INP000005722@@MARATHON TRENDS ADVISORY PRIVATE LIMITED -> MARATHON TRENDS ADVISORY PRIVATE LIMITED
# INP000006183@@INP000006183@@MARCELLUS INVESTMENT MANAGERS PRIVATE LIMITED -> MARCELLUS INVESTMENT MANAGERS PRIVATE LIMITED
# INP000005117@@INP000005117@@MARFATIA STOCK BROKING PRIVATE LIMITED -> MARFATIA STOCK BROKING PRIVATE LIMITED
# INP000007890@@INP000007890@@MARKETS MOJO ASSET MANAGEMENT PRIVATE LIMITED -> MARKETS MOJO ASSET MANAGEMENT PRIVATE LIMITED
# INP000001637@@INP000001637@@MASTER PORTFOLIO SERVICES LTD -> MASTER PORTFOLIO SERVICES LTD
# INP000007313@@INP000007313@@MAXIMAL CAPITAL PRIVATE LIMITED -> MAXIMAL CAPITAL PRIVATE LIMITED
# INP000005971@@INP000005971@@MEHTA EQUITIES LIMITED -> MEHTA EQUITIES LIMITED
# INP000006846@@INP000006846@@MERISIS ADVISORS PRIVATE LIMITED -> MERISIS ADVISORS PRIVATE LIMITED
# INP000006086@@INP000006086@@MICROSEC WEALTH MANAGEMENT LIMITED  -> MICROSEC WEALTH MANAGEMENT LIMITED
# INP000002643@@INP000002643@@MILESTONE CAPITAL ADVISORS PRIVATE LIMITED -> MILESTONE CAPITAL ADVISORS PRIVATE LIMITED
# INP000001447@@INP000001447@@MILLENNIUM FINANCE LTD. -> MILLENNIUM FINANCE LTD.
# INP000009409@@INP000009409@@MIRAE ASSET INVESTMENT MANAGERS INDIA PRIVATE LIMITED -> MIRAE ASSET INVESTMENT MANAGERS INDIA PRIVATE LIMITED
# INP000006730@@INP000006730@@MITTAL ANALYTICS PRIVATE LIMITED -> MITTAL ANALYTICS PRIVATE LIMITED
# INP000001413@@INP000001413@@MIV INVESTMENT SERVICES PVT. LTD. -> MIV INVESTMENT SERVICES PVT. LTD.
# INP000004920@@INP000004920@@MO ALTERNATE INVESTMENT ADVISORS PRIVATE LIMITED -> MO ALTERNATE INVESTMENT ADVISORS PRIVATE LIMITED
# INP000004482@@INP000004482@@MOAT FINANCIAL SERVICES PRIVATE LIMITED -> MOAT FINANCIAL SERVICES PRIVATE LIMITED
# INP000007216@@INP000007216@@MOLECULE VENTURES LLP -> MOLECULE VENTURES LLP
# INP000006059@@INP000006059@@MONARCH NETWORTH CAPITAL LIMITED -> MONARCH NETWORTH CAPITAL LIMITED
# INP000001959@@INP000001959@@MONEYBEE SECURITIES PRIVATE LIMITED -> MONEYBEE SECURITIES PRIVATE LIMITED
# INP000007915@@INP000007915@@MONEYGROW ASSET PRIVATE LIMITED -> MONEYGROW ASSET PRIVATE LIMITED
# INP000006873@@INP000006873@@MONEYLIFE ADVISORY SERVICES PVT LTD -> MONEYLIFE ADVISORY SERVICES PVT LTD
# INP000006156@@INP000006156@@MORNINGSTAR INVESTMENT ADVISER INDIA PRIVATE LIMITED -> MORNINGSTAR INVESTMENT ADVISER INDIA PRIVATE LIMITED
# INP000000670@@INP000000670@@MOTILAL OSWAL ASSET MANAGEMENT COMPANY LIMITED -> MOTILAL OSWAL ASSET MANAGEMENT COMPANY LIMITED
# INP000006776@@INP000006776@@MOTILAL OSWAL CAPITAL LIMITED -> MOTILAL OSWAL CAPITAL LIMITED
# INP000006712@@INP000006712@@MOTILAL OSWAL FINANCIAL SERVICES LIMITED -> MOTILAL OSWAL FINANCIAL SERVICES LIMITED
# INP000004409@@INP000004409@@MOTILAL OSWAL WEALTH LIMITED -> MOTILAL OSWAL WEALTH LIMITED
# INP000006253@@INP000006253@@MRG INVESTMENT PARTNERS PRIVATE LIMITED -> MRG INVESTMENT PARTNERS PRIVATE LIMITED
# INP000002965@@INP000002965@@MULTI-ACT EQUITY CONSULTANCY PVT LTD -> MULTI-ACT EQUITY CONSULTANCY PVT LTD
# INP000007429@@INP000007429@@MULTIPLES ALTERNATE ASSET MANAGEMENT PRIVATE LIMITED -> MULTIPLES ALTERNATE ASSET MANAGEMENT PRIVATE LIMITED
# INP000000308@@INP000000308@@MUNOTH FINANCIAL SERVICES LTD -> MUNOTH FINANCIAL SERVICES LTD
# INP000006989@@INP000006989@@NAFA ASSET MANAGERS PRIVATE LIMITED -> NAFA ASSET MANAGERS PRIVATE LIMITED
# INP000006420@@INP000006420@@NARNOLIA  FINANCIAL SERVICES LTD -> NARNOLIA  FINANCIAL SERVICES LTD
# INP000005414@@INP000005414@@NEGEN CAPITAL SERVICES PRIVATE LIMITED -> NEGEN CAPITAL SERVICES PRIVATE LIMITED
# INP000007641@@INP000007641@@NEO ASSET MANAGEMENT PRIVATE LIMITED -> NEO ASSET MANAGEMENT PRIVATE LIMITED
# INP000008738@@INP000008738@@NEOLIV CAPITAL ADVISORY PRIVATE LIMITED -> NEOLIV CAPITAL ADVISORY PRIVATE LIMITED
# INP000005323@@INP000005323@@NEW BERRY CAPITALS PVT. LTD. -> NEW BERRY CAPITALS PVT. LTD.
# INP000002452@@INP000002452@@NEW HORIZON WEALTH MANAGEMENT PRIVATE LIMITED -> NEW HORIZON WEALTH MANAGEMENT PRIVATE LIMITED
# INP000007067@@INP000007067@@NEW MARK ADVISORS LLP -> NEW MARK ADVISORS LLP
# INP000004169@@INP000004169@@NINE RIVERS CAPITAL HOLDINGS PRIVATE LIMITED -> NINE RIVERS CAPITAL HOLDINGS PRIVATE LIMITED
# INP000008242@@INP000008242@@NIPPON LIFE INDIA AIF MANAGEMENT LIMITED -> NIPPON LIFE INDIA AIF MANAGEMENT LIMITED
# INP000007085@@INP000007085@@NIPPON LIFE INDIA ASSET MANAGEMENT LIMITED  -> NIPPON LIFE INDIA ASSET MANAGEMENT LIMITED
# INP000002981@@INP000002981@@NIRMAL BANG SECURITIES PRIVATE LIMITED -> NIRMAL BANG SECURITIES PRIVATE LIMITED
# INP000003518@@INP000003518@@NJ ASSET MANAGEMENT PRIVATE LIMITED -> NJ ASSET MANAGEMENT PRIVATE LIMITED
# INP000009108@@INP000009108@@NMR CAPITAL ADVISORS LLP -> NMR CAPITAL ADVISORS LLP
# INP000007100@@INP000007100@@NNM SECURITIES PRIVATE LIMITED -> NNM SECURITIES PRIVATE LIMITED
# INP200007265@@INP200007265@@NORTHERN ARC INVESTMENT MANAGERS PRIVATE LIMITED -> NORTHERN ARC INVESTMENT MANAGERS PRIVATE LIMITED
# INP000007207@@INP000007207@@NUVAMA ASSET MANAGEMENT LIMITED -> NUVAMA ASSET MANAGEMENT LIMITED
# INP000008400@@INP000008400@@NV ALPHA FUND MANAGEMENT LLP -> NV ALPHA FUND MANAGEMENT LLP
# INP000006624@@INP000006624@@OAKLANE CAPITAL MANAGEMENT LLP -> OAKLANE CAPITAL MANAGEMENT LLP
# INP000004888@@INP000004888@@OAKS ASSET MANAGEMENT PRIVATE LIMITED -> OAKS ASSET MANAGEMENT PRIVATE LIMITED
# INP000006174@@INP000006174@@OCEAN DIAL ASSET MANAGEMENT INDIA PRIVATE LIMITED -> OCEAN DIAL ASSET MANAGEMENT INDIA PRIVATE LIMITED
# INP000001389@@INP000001389@@OHM PORTFOLIO EQUI RESEARCH PVT LTD. -> OHM PORTFOLIO EQUI RESEARCH PVT LTD.
# INP000005174@@INP000005174@@OLD BRIDGE CAPITAL MANAGEMENT PVT. LTD. -> OLD BRIDGE CAPITAL MANAGEMENT PVT. LTD.
# INP000007508@@INP000007508@@ORIOS ADVISORS LLP -> ORIOS ADVISORS LLP
# INP000006882@@INP000006882@@ORO ASSET MANAGEMENT PRIVATE LIMITED -> ORO ASSET MANAGEMENT PRIVATE LIMITED
# INP000002338@@INP000002338@@P.C.S SECURITIES LIMITED -> P.C.S SECURITIES LIMITED
# INP000006998@@INP000006998@@PACE FINANCIAL INVESTMENT ADVISER PRIVATE LIMITED -> PACE FINANCIAL INVESTMENT ADVISER PRIVATE LIMITED
# INP000005731@@INP000005731@@PANTOMATH FUND MANAGERS PRIVATE LIMITED -> PANTOMATH FUND MANAGERS PRIVATE LIMITED
# INP000000241@@INP000000241@@PARAG PARIKH FINANCIAL ADVISORY SERVICES LIMITED -> PARAG PARIKH FINANCIAL ADVISORY SERVICES LIMITED
# INP000005422@@INP000005422@@PATERSON SECURITIES PRIVATE LTD -> PATERSON SECURITIES PRIVATE LTD
# INP000008631@@INP000008631@@PAVESTONE ADVISORS AND CONSULTANTS LLP -> PAVESTONE ADVISORS AND CONSULTANTS LLP
# INP000006891@@INP000006891@@PELICAN HOLDINGS PRIVATE LIMITED -> PELICAN HOLDINGS PRIVATE LIMITED
# INP000006095@@INP000006095@@PENBROOK INVESTMENT MANAGER LLP -> PENBROOK INVESTMENT MANAGER LLP
# INP000006952@@INP000006952@@PGIM INDIA ASSET MANAGEMENT PRIVATE LIMITED -> PGIM INDIA ASSET MANAGEMENT PRIVATE LIMITED
# INP000009047@@INP000009047@@PHI CAPITAL SOLUTIONS LLP -> PHI CAPITAL SOLUTIONS LLP
# INP000004433@@INP000004433@@PHILLIPCAPITAL (INDIA) PRIVATE LIMITED -> PHILLIPCAPITAL (INDIA) PRIVATE LIMITED
# INP100007231@@INP100007231@@PIONEER CLIENT ASSOCIATES PRIVATE LIMITED -> PIONEER CLIENT ASSOCIATES PRIVATE LIMITED
# INP000005364@@INP000005364@@PIONEER INVESTCORP LIMITED -> PIONEER INVESTCORP LIMITED
# INP000005883@@INP000005883@@PIONEER WEALTH MANAGEMENT SERVICES LIMITED -> PIONEER WEALTH MANAGEMENT SERVICES LIMITED
# INP000006749@@INP000006749@@PIPER SERICA ADVISORS PRIVATE LIMITED  -> PIPER SERICA ADVISORS PRIVATE LIMITED
# INP000004136@@INP000004136@@PIRAMAL FUND MANAGEMENT PRIVATE LIMITED -> PIRAMAL FUND MANAGEMENT PRIVATE LIMITED
# INP000009001@@INP000009001@@PL ASSET MANAGEMENT PRIVATE LIMITED -> PL ASSET MANAGEMENT PRIVATE LIMITED
# INP000009144@@INP000009144@@PLUSWEALTH CAPITAL MANAGEMENT LLP -> PLUSWEALTH CAPITAL MANAGEMENT LLP
# INP000008279@@INP000008279@@PRABHUDAS LILLADHER PRIVATE LIMITED -> PRABHUDAS LILLADHER PRIVATE LIMITED
# INP000001231@@INP000001231@@PRABHUDAS LILLADHER PVT. LTD. -> PRABHUDAS LILLADHER PVT. LTD.
# INP100007286@@INP100007286@@PRESCIENTCAP INVESTMENT ADVISORS LLP -> PRESCIENTCAP INVESTMENT ADVISORS LLP
# INP000000951@@INP000000951@@PRINCIPAL ASSET MANAGEMENT PVT LTD -> PRINCIPAL ASSET MANAGEMENT PVT LTD
# INP000004441@@INP000004441@@PRITHVI FINMART PRIVATE LIMITED -> PRITHVI FINMART PRIVATE LIMITED
# INP000007836@@INP000007836@@PROFIT BLOOM PRIVATE LIMITED -> PROFIT BLOOM PRIVATE LIMITED
# INP000008233@@INP000008233@@PROFITGATE CAPITAL SERVICES LLP -> PROFITGATE CAPITAL SERVICES LLP
# INP000007173@@INP000007173@@PROFUSION INVESTMENT ADVISORS LLP -> PROFUSION INVESTMENT ADVISORS LLP
# INP000008817@@INP000008817@@PROGRESSIVE SHARE BROKERS PRIVATE LIMITED -> PROGRESSIVE SHARE BROKERS PRIVATE LIMITED
# INP000006800@@INP000006800@@PROPSHARE CAPITAL ADVISORS PRIVATE LIMITED -> PROPSHARE CAPITAL ADVISORS PRIVATE LIMITED
# INP000007049@@INP000007049@@PROSPERITY WEALTH MANAGEMENT PRIVATE LIMITED -> PROSPERITY WEALTH MANAGEMENT PRIVATE LIMITED
# INP000008677@@INP000008677@@PROSPERO TREE ASSET MANAGEMENT LLP -> PROSPERO TREE ASSET MANAGEMENT LLP
# INP000007960@@INP000007960@@PRP EDGE WEALTH PRIVATE LIMITED -> PRP EDGE WEALTH PRIVATE LIMITED
# INP100007259@@INP100007259@@PRP PROFESSIONAL EDGE ASSOCIATES PVT LTD. -> PRP PROFESSIONAL EDGE ASSOCIATES PVT LTD.
# INP000008686@@INP000008686@@PRUDENT EQUITY PRIVATE LIMITED -> PRUDENT EQUITY PRIVATE LIMITED
# INP000007298@@INP000007298@@PRUDENT INVESTMENT MANAGERS LLP -> PRUDENT INVESTMENT MANAGERS LLP
# INP000007021@@INP000007021@@PURNARTHA INVESTMENT ADVISERS PVT.LTD. -> PURNARTHA INVESTMENT ADVISERS PVT.LTD.
# INP000009366@@INP000009366@@PURVA ASSET MANAGEMENT PRIVATE LIMITED -> PURVA ASSET MANAGEMENT PRIVATE LIMITED
# INP000005075@@INP000005075@@QED CAPITAL ADVISORS LLP -> QED CAPITAL ADVISORS LLP
# INP000008914@@INP000008914@@QODE ADVISORS LLP -> QODE ADVISORS LLP
# INP000005892@@INP000005892@@QRC INVESTMENT ADVISORS LLP -> QRC INVESTMENT ADVISORS LLP
# INP000005042@@INP000005042@@QUANT PORTFOLIO MANAGERS PRIVATE LIMITED -> QUANT PORTFOLIO MANAGERS PRIVATE LIMITED
# INP000000187@@INP000000187@@QUANTUM ADVISORS PVT.LTD. -> QUANTUM ADVISORS PVT.LTD.
# INP000001421@@INP000001421@@QUEST INVESTMENT ADVISORS PVT. LTD. -> QUEST INVESTMENT ADVISORS PVT. LTD.
# INP000004045@@INP000004045@@R. WADIWALA SECURITIES PRIVATE LIMITED -> R. WADIWALA SECURITIES PRIVATE LIMITED
# INP000008048@@INP000008048@@RBSA INVESTMENT MANAGER LLP -> RBSA INVESTMENT MANAGER LLP
# INP000002353@@INP000002353@@RELIANCE WEALTH MANAGEMENT LIMITED -> RELIANCE WEALTH MANAGEMENT LIMITED
# INP000005455@@INP000005455@@RENAISSANCE INVESTMENT MANAGERS PRIVATE LIMITED -> RENAISSANCE INVESTMENT MANAGERS PRIVATE LIMITED
# INP000004003@@INP000004003@@REVELATION PORTFOLIO MANAGEMENT PVT. LTD. -> REVELATION PORTFOLIO MANAGEMENT PVT. LTD.
# INP000004359@@INP000004359@@RIGHT HORIZONS PORTFOLIO MANAGEMENT PRIVATE LIMITED -> RIGHT HORIZONS PORTFOLIO MANAGEMENT PRIVATE LIMITED
# INP000007924@@INP000007924@@ROCKSTUD CAPITAL LLP -> ROCKSTUD CAPITAL LLP
# INP000007030@@INP000007030@@ROHA ASSET MANAGERS LLP -> ROHA ASSET MANAGERS LLP
# INP000006369@@INP000006369@@ROWAN CAPITAL ADVISORS LLP -> ROWAN CAPITAL ADVISORS LLP
# INP000007456@@INP000007456@@RP-SG VENTURES ADVISORY LLP -> RP-SG VENTURES ADVISORY LLP
# INP000006943@@INP000006943@@SAGEONE INVESTMENT MANAGERS LLP -> SAGEONE INVESTMENT MANAGERS LLP
# INP000007386@@INP000007386@@SAHASRAR CAPITAL PRIVATE LIMITED -> SAHASRAR CAPITAL PRIVATE LIMITED
# INP000009348@@INP000009348@@SAMATVA INVESTMENT ADVISERS LLP -> SAMATVA INVESTMENT ADVISERS LLP
# INP000004995@@INP000004995@@SAMEEKSHA CAPITAL PRIVATE LIMITED -> SAMEEKSHA CAPITAL PRIVATE LIMITED
# INP000004847@@INP000004847@@SAMVITTI CAPITAL PRIVATE LIMITED -> SAMVITTI CAPITAL PRIVATE LIMITED
# INP000005067@@INP000005067@@SANCTUM WEALTH PRIVATE LIMITED -> SANCTUM WEALTH PRIVATE LIMITED
# INP000003492@@INP000003492@@SATCO CAPITAL MARKETS LTD -> SATCO CAPITAL MARKETS LTD
# INP000005331@@INP000005331@@SAVVY CAPITAL ADVISORS LLP -> SAVVY CAPITAL ADVISORS LLP
# INP000000852@@INP000000852@@SBI FUNDS MANAGEMENT LIMITED -> SBI FUNDS MANAGEMENT LIMITED
# INP000004912@@INP000004912@@SBICAP SECURITIES LIMITED -> SBICAP SECURITIES LIMITED
# INP000005166@@INP000005166@@SCIENT CAPITAL PRIVATE LIMITED -> SCIENT CAPITAL PRIVATE LIMITED
# INP000002940@@INP000002940@@SECURITIES INVESTMENT MANAGEMENT PRIVATE LIMITED -> SECURITIES INVESTMENT MANAGEMENT PRIVATE LIMITED
# INP000005398@@INP000005398@@SEERS FUND MANAGEMENT PRIVATE LIMITED -> SEERS FUND MANAGEMENT PRIVATE LIMITED
# INP000008543@@INP000008543@@SEKURA INDIA MANAGEMENT LIMITED -> SEKURA INDIA MANAGEMENT LIMITED
# INP000004516@@INP000004516@@SERAPHIC MANAGEMENT & ADVISORY PRIVATE LIMITED -> SERAPHIC MANAGEMENT & ADVISORY PRIVATE LIMITED
# INP000004185@@INP000004185@@SHADE CAPITAL PRIVATE LIMITED -> SHADE CAPITAL PRIVATE LIMITED
# INP000005926@@INP000005926@@SHARE INDIA SECURITIES LIMITED -> SHARE INDIA SECURITIES LIMITED
# INP000005786@@INP000005786@@SHAREKHAN LIMITED -> SHAREKHAN LIMITED
# INP000004748@@INP000004748@@SHEPHERDS HILL FINANCIAL ADVISORS LLP -> SHEPHERDS HILL FINANCIAL ADVISORS LLP
# INP300007341@@INP300007341@@SHREE RAMA MANAGERS LLP -> SHREE RAMA MANAGERS LLP
# INP000008765@@INP000008765@@SHRIRAM ASSET MANAGEMENT COMPANY LIMITED -> SHRIRAM ASSET MANAGEMENT COMPANY LIMITED
# INP000003823@@INP000003823@@SHROFF SECURITIES PRIVATE LIMITED -> SHROFF SECURITIES PRIVATE LIMITED
# INP000008118@@INP000008118@@SILA ADVISORS LLP -> SILA ADVISORS LLP
# INP000005759@@INP000005759@@SILVERARCH INVESTMENT ADVISERS PRIVATE LIMITED -> SILVERARCH INVESTMENT ADVISERS PRIVATE LIMITED
# INP200007803@@INP200007803@@SINCERE SYNDICATION AND CORPORATE SERVICES LLP -> SINCERE SYNDICATION AND CORPORATE SERVICES LLP
# INP200007663@@INP200007663@@SINGULAR CAPITAL INDIA ADVISORS LLP -> SINGULAR CAPITAL INDIA ADVISORS LLP
# INP000007474@@INP000007474@@SINGULARITY AMC LLP -> SINGULARITY AMC LLP
# INP000004615@@INP000004615@@SIRIUS ADVISORS PRIVATE LIMITED -> SIRIUS ADVISORS PRIVATE LIMITED
# INP000006509@@INP000006509@@SKP SECURITIES LIMITED -> SKP SECURITIES LIMITED
# INP000006165@@INP000006165@@SKY IMPACT CAPITAL ADVISORS LLP -> SKY IMPACT CAPITAL ADVISORS LLP
# INP000006819@@INP000006819@@SMARTOWNER SERVICES INDIA PVT. LTD. -> SMARTOWNER SERVICES INDIA PVT. LTD.
# INP000006703@@INP000006703@@SMC GLOBAL SECURITIES LIMITED -> SMC GLOBAL SECURITIES LIMITED
# INP000008136@@INP000008136@@SOHUM ASSET MANAGERS PRIVATE LIMITED -> SOHUM ASSET MANAGERS PRIVATE LIMITED
# INP000004318@@INP000004318@@SOLDIERS FIELD INVESTMENTS PRIVATE LIMITED -> SOLDIERS FIELD INVESTMENTS PRIVATE LIMITED
# INP000004961@@INP000004961@@SOLIDARITY ADVISORS PRIVATE LIMITED -> SOLIDARITY ADVISORS PRIVATE LIMITED
# INP000009357@@INP000009357@@SOMERSET HEALTHCARE INVESTMENT ADVISORS III PRIVATE LIMITED -> SOMERSET HEALTHCARE INVESTMENT ADVISORS III PRIVATE LIMITED
# INP000008127@@INP000008127@@SOWILO INVESTMENT MANAGERS LLP -> SOWILO INVESTMENT MANAGERS LLP
# INP000004664@@INP000004664@@SPA CAPITAL ADVISORS LIMITED -> SPA CAPITAL ADVISORS LIMITED
# INP000006235@@INP000006235@@SPARK ASIA IMPACT MANAGERS PRIVATE LIMITED  -> SPARK ASIA IMPACT MANAGERS PRIVATE LIMITED
# INP000008835@@INP000008835@@SPARK FUND ADVISORS LLP -> SPARK FUND ADVISORS LLP
# INP200007274@@INP200007274@@SPARK PWM PRIVATE LIMITED  -> SPARK PWM PRIVATE LIMITED
# INP200007566@@INP200007566@@SPECIALE INCEPT ADVISORS LLP -> SPECIALE INCEPT ADVISORS LLP
# INP000008978@@INP000008978@@SPICE ROUTE ADVISORS LLP -> SPICE ROUTE ADVISORS LLP
# INP000008862@@INP000008862@@SQUARE 64 CAPITAL ADVISORS LLP -> SQUARE 64 CAPITAL ADVISORS LLP
# INP000006129@@INP000006129@@STALLION ASSET PRIVATE LIMITED -> STALLION ASSET PRIVATE LIMITED
# INP000007757@@INP000007757@@STALWART INVESTMENT ADVISORS LLP -> STALWART INVESTMENT ADVISORS LLP
# INP000006864@@INP000006864@@STAMPEDE CAPITAL LIMITED -> STAMPEDE CAPITAL LIMITED
# INP000003542@@INP000003542@@STANDARD CHARTERED SECURITIES (INDIA) LIMITED -> STANDARD CHARTERED SECURITIES (INDIA) LIMITED
# INP000008598@@INP000008598@@STEPTRADE SHARE SERVICES PRIVATE LIMITED -> STEPTRADE SHARE SERVICES PRIVATE LIMITED
# INP000004623@@INP000004623@@STEWART  AND  MACKERTICH WEALTH MANAGEMENT LIMITED -> STEWART  AND  MACKERTICH WEALTH MANAGEMENT LIMITED
# INP000007304@@INP000007304@@STOCKHOLDING SERVICES LIMITED -> STOCKHOLDING SERVICES LIMITED
# INP000005962@@INP000005962@@STRUGENCE CAPITAL ADVISORS LLP -> STRUGENCE CAPITAL ADVISORS LLP
# INP000006642@@INP000006642@@SUMPOORNA PORTFOLIO LIMITED -> SUMPOORNA PORTFOLIO LIMITED
# INP000006271@@INP000006271@@SUNDARAM ALTERNATE ASSETS LIMITED  -> SUNDARAM ALTERNATE ASSETS LIMITED
# INP000006572@@INP000006572@@SUPREMUS CAPITAL ADVISORS LLP -> SUPREMUS CAPITAL ADVISORS LLP
# INP000001082@@INP000001082@@SUREFIN FINANCIAL CONSULTANTS PVT. LTD -> SUREFIN FINANCIAL CONSULTANTS PVT. LTD
# INP000007988@@INP000007988@@SVAN INVESTMENT MANAGERS LLP -> SVAN INVESTMENT MANAGERS LLP
# INP000008011@@INP000008011@@SVOBODHA INFINITY INVESTMENT ADVISORS PRIVATE LIMITED -> SVOBODHA INFINITY INVESTMENT ADVISORS PRIVATE LIMITED
# INP000005935@@INP000005935@@SW1 ADVISORY PRIVATE LIMITED -> SW1 ADVISORY PRIVATE LIMITED
# INP000008181@@INP000008181@@SWASTIKA INVESTMART LIMITED -> SWASTIKA INVESTMART LIMITED
# INP300007712@@INP300007712@@SWYOM ADVISORS LIMITED -> SWYOM ADVISORS LIMITED
# INP000005795@@INP000005795@@SYKES  AND  RAY EQUITIES INDIA LIMITED -> SYKES  AND  RAY EQUITIES INDIA LIMITED
# INP000002692@@INP000002692@@SYSTEMATIX SHARES AND STOCKS (INDIA) LIMITED -> SYSTEMATIX SHARES AND STOCKS (INDIA) LIMITED
# INP000006068@@INP000006068@@T.RAM FINANCIAL SERVICES PRIVATE LIMITED -> T.RAM FINANCIAL SERVICES PRIVATE LIMITED
# INP000008871@@INP000008871@@TAILWIND FINANCIAL SERVICES PRIVATE LIMITED -> TAILWIND FINANCIAL SERVICES PRIVATE LIMITED
# INP000004763@@INP000004763@@TAMOHARA INVESTMENT MANAGERS PRIVATE LIMITED -> TAMOHARA INVESTMENT MANAGERS PRIVATE LIMITED
# INP000008020@@INP000008020@@TAMOHARA INVESTMENT MANAGERS PRIVATE LIMITED -> TAMOHARA INVESTMENT MANAGERS PRIVATE LIMITED
# INP000001058@@INP000001058@@TATA ASSET MANAGEMENT PRIVATE LIMITED -> TATA ASSET MANAGEMENT PRIVATE LIMITED
# INP000004490@@INP000004490@@TAURUS TREASURY MANAGEMENT SERVICES PRIVATE LIMITED -> TAURUS TREASURY MANAGEMENT SERVICES PRIVATE LIMITED
# INP000005133@@INP000005133@@TCG ADVISORY SERVICES PRIVATE LIMITED -> TCG ADVISORY SERVICES PRIVATE LIMITED
# INP000005356@@INP000005356@@THAUMATURGY CAPITAL SERVICES PRIVATE LIMITED -> THAUMATURGY CAPITAL SERVICES PRIVATE LIMITED
# INP000000795@@INP000000795@@THE HONGKONG AND SHANGHAI BANKING CORPOR -> THE HONGKONG AND SHANGHAI BANKING CORPOR
# INP000008109@@INP000008109@@THINQWISE WEALTH MANAGERS LLP -> THINQWISE WEALTH MANAGERS LLP
# INP000006475@@INP000006475@@THIRANI SECURITIES PVT.LTD. -> THIRANI SECURITIES PVT.LTD.
# INP000005141@@INP000005141@@TIPSONS CONSULTANCY SERVICES PRIVATE LIMITED -> TIPSONS CONSULTANCY SERVICES PRIVATE LIMITED
# INP000008251@@INP000008251@@TORUS ORO PORTFOLIO MANAGEMENT PRIVATE LIMITED -> TORUS ORO PORTFOLIO MANAGEMENT PRIVATE LIMITED
# INP000008446@@INP000008446@@TRADESWIFT BROKING PRIVATE LIMITED -> TRADESWIFT BROKING PRIVATE LIMITED
# INP000004656@@INP000004656@@TRIVANTAGE CAPITAL MANAGMENT INDIA PRIVATE LIMITED -> TRIVANTAGE CAPITAL MANAGMENT INDIA PRIVATE LIMITED
# INP200007353@@INP200007353@@TRUE BEACON INVESTMENT ADVISORS LLP -> TRUE BEACON INVESTMENT ADVISORS LLP
# INP000007748@@INP000007748@@TRUE NORTH CREDIT FUND MANAGERS LLP -> TRUE NORTH CREDIT FUND MANAGERS LLP
# INP000008002@@INP000008002@@TRUE NORTH MANAGERS LLP -> TRUE NORTH MANAGERS LLP
# INP000001843@@INP000001843@@TRUST INVESTMENT ADVISORS PVT. LTD. -> TRUST INVESTMENT ADVISORS PVT. LTD.
# INP000002254@@INP000002254@@TRUSTLINE HOLDING PVT. LTD. -> TRUSTLINE HOLDING PVT. LTD.
# INP000004268@@INP000004268@@TRUSTLINE SECURITIES LIMITED -> TRUSTLINE SECURITIES LIMITED
# INP000005838@@INP000005838@@TULSIAN PMS LIMITED -> TULSIAN PMS LIMITED
# INP000006758@@INP000006758@@TURTLE WEALTH MANAGEMENT PVT. LTD. -> TURTLE WEALTH MANAGEMENT PVT. LTD.
# INP000004466@@INP000004466@@TVS CAPITAL FUNDS PRIVATE LIMITED -> TVS CAPITAL FUNDS PRIVATE LIMITED
# INP000008923@@INP000008923@@UNICORN INVESTMENT MANAGERS LLP -> UNICORN INVESTMENT MANAGERS LLP
# INP000000613@@INP000000613@@UNIFI CAPITAL PRIVATE LIMITED -> UNIFI CAPITAL PRIVATE LIMITED
# INP000006855@@INP000006855@@UNIQUE ASSET MANAGEMENT LLP -> UNIQUE ASSET MANAGEMENT LLP
# INP000007526@@INP000007526@@UTI ALTERNATIVES PRIVATE LIMITED -> UTI ALTERNATIVES PRIVATE LIMITED
# INP000000860@@INP000000860@@UTI ASSET MANAGEMENT COMPANY PVT LTD -> UTI ASSET MANAGEMENT COMPANY PVT LTD
# INP000006244@@INP000006244@@V. P. CONSULTANTS PRIVATE LIMITED -> V. P. CONSULTANTS PRIVATE LIMITED
# INP000008701@@INP000008701@@V.E.C ASSAGO CAPITAL MANAGEMENT LLP -> V.E.C ASSAGO CAPITAL MANAGEMENT LLP
# INP000004581@@INP000004581@@VAL-Q INVESTMENT ADVISORY PRIVATE LIMITED -> VAL-Q INVESTMENT ADVISORY PRIVATE LIMITED
# INP000005980@@INP000005980@@VALCREATE INVESTMENT MANAGERS LLP -> VALCREATE INVESTMENT MANAGERS LLP
# INP000007599@@INP000007599@@VALCREATE INVESTMENT MANAGERS LLP -> VALCREATE INVESTMENT MANAGERS LLP
# INP000005125@@INP000005125@@VALENTIS ADVISORS PRIVATE LIMITED -> VALENTIS ADVISORS PRIVATE LIMITED
# INP000007650@@INP000007650@@VALLUM CAPITAL ADVISORS PRIVATE LIMITED -> VALLUM CAPITAL ADVISORS PRIVATE LIMITED
# INP000006961@@INP000006961@@VALLUM CAPITAL ADVISORS PRIVATE LIMITED -> VALLUM CAPITAL ADVISORS PRIVATE LIMITED
# INP100007578@@INP100007578@@VALTRUST PARTNERS LLP -> VALTRUST PARTNERS LLP
# INP100007189@@INP100007189@@VALUE PROLIFIC INVESTMENTS AND CONSULTING PRIVATE LIMITED -> VALUE PROLIFIC INVESTMENTS AND CONSULTING PRIVATE LIMITED
# INP000003724@@INP000003724@@VALUEQUEST INVESTMENT ADVISORS PVT. LTD. -> VALUEQUEST INVESTMENT ADVISORS PVT. LTD.
# INP000005281@@INP000005281@@VARANIUM CAPITAL ADVISORS PRIVATE LIMITED -> VARANIUM CAPITAL ADVISORS PRIVATE LIMITED
# INP000004094@@INP000004094@@VENTURA SECURITIES LIMITED -> VENTURA SECURITIES LIMITED
# INP000005091@@INP000005091@@VITOR FUND MANAGERS LLP -> VITOR FUND MANAGERS LLP
# INP000008330@@INP000008330@@VIVRITI ASSET MANAGEMENT PRIVATE LIMITED -> VIVRITI ASSET MANAGEMENT PRIVATE LIMITED
# INP000009083@@INP000009083@@VSPARTANS CONSULTANTS PRIVATE LIMITED -> VSPARTANS CONSULTANTS PRIVATE LIMITED
# INP000006226@@INP000006226@@WADHAWAN WEALTH MANAGERS PRIVATE LIMITED -> WADHAWAN WEALTH MANAGERS PRIVATE LIMITED
# INP000006192@@INP000006192@@WALLFORT PMS  AND  ADVISORY SERVICES LLP  -> WALLFORT PMS  AND  ADVISORY SERVICES LLP
# INP000007818@@INP000007818@@WATERFIELD FINANCIAL AND INVESTMENT ADVISORS PRIVATE LIMITED -> WATERFIELD FINANCIAL AND INVESTMENT ADVISORS PRIVATE LIMITED
# INP000008288@@INP000008288@@WATERFIELD FUND MANAGERS PRIVATE LIMITED -> WATERFIELD FUND MANAGERS PRIVATE LIMITED
# INP000008428@@INP000008428@@WAVE ASSET PRIVATE LIMITED -> WAVE ASSET PRIVATE LIMITED
# INP000000829@@INP000000829@@WAY2WEALTH  BROKERS PRIVATE LTD. -> WAY2WEALTH  BROKERS PRIVATE LTD.
# INP000008987@@INP000008987@@WAYA FINANCIAL TECHNOLOGIES PRIVATE LIMITED -> WAYA FINANCIAL TECHNOLOGIES PRIVATE LIMITED
# INP000006332@@INP000006332@@WEALTH FIRST PORTFOLIO MANAGERS LIMITED -> WEALTH FIRST PORTFOLIO MANAGERS LIMITED
# INP000009393@@INP000009393@@WEALTH INDIA FINANCIAL SERVICES PRIVATE LIMITED -> WEALTH INDIA FINANCIAL SERVICES PRIVATE LIMITED
# INP000001660@@INP000001660@@WEALTH MANAGERS INDIA PRIVATE LIMITED -> WEALTH MANAGERS INDIA PRIVATE LIMITED
# INP000005240@@INP000005240@@WEALTHBRIDGE CAPITAL ADVISORS PRIVATE LIMITED -> WEALTHBRIDGE CAPITAL ADVISORS PRIVATE LIMITED
# INP000005768@@INP000005768@@WELLWORTH SHARE AND STOCK BROKING LTD -> WELLWORTH SHARE AND STOCK BROKING LTD
# INP000007997@@INP000007997@@WELSPUN ONE LOGISTICS PARKS PRIVATE LIMITED -> WELSPUN ONE LOGISTICS PARKS PRIVATE LIMITED
# INP000005865@@INP000005865@@WHITE OAK CAPITAL MANAGEMENT CONSULTANTS LLP -> WHITE OAK CAPITAL MANAGEMENT CONSULTANTS LLP
# INP000007331@@INP000007331@@WHITE PINE INVESTMENT MANAGEMENT PRIVATE LIMITED -> WHITE PINE INVESTMENT MANAGEMENT PRIVATE LIMITED
# INP000006970@@INP000006970@@WHITE WHALE PARTNERS LLP -> WHITE WHALE PARTNERS LLP
# INP000007766@@INP000007766@@WHITEOAK CAPITAL ASSET MANAGEMENT LIMITED -> WHITEOAK CAPITAL ASSET MANAGEMENT LIMITED
# INP000006925@@INP000006925@@WILLOW ADVISORS LLP -> WILLOW ADVISORS LLP
# INP000007979@@INP000007979@@WRYGHT RESEARCH  AND  CAPITAL PRIVATE LIMITED -> WRYGHT RESEARCH  AND  CAPITAL PRIVATE LIMITED
# INP000009092@@INP000009092@@WSB REAL ESTATE PARTNERS PVT LTD -> WSB REAL ESTATE PARTNERS PVT LTD
# INP000005953@@INP000005953@@WYRIDIAN ADVISORS LLP -> WYRIDIAN ADVISORS LLP
# INP000008516@@INP000008516@@XPONENT TRIBE LLP -> XPONENT TRIBE LLP
# INP000007483@@INP000007483@@XPONENTIA CAPITAL PARTNERS LLP -> XPONENTIA CAPITAL PARTNERS LLP
# INP000000936@@INP000000936@@ZEN WEALTH MANAGEMENT SERVICES LIMITED -> ZEN WEALTH MANAGEMENT SERVICES LIMITED
# INP000007872@@INP000007872@@ZEVA CAPSOL PRIVATE LIMITED  -> ZEVA CAPSOL PRIVATE LIMITED

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import calendar

# def fetch_tables_with_titles(pmr_id, year, month):
#     """
#     Fetch tables with their titles from the PMR page for given year and month.
#     Returns a dict: { "XX - Table Title": [ [row1], [row2], ... ] }
#     """
#     url = "https://www.sebi.gov.in/sebiweb/other/OtherAction.do?doPmr=yes"

#     headers = {
#         "User-Agent": "Mozilla/5.0",
#         "Referer": url,
#         "Origin": "https://www.sebi.gov.in"
#     }

#     payload = {
#         "pmrId": pmr_id,
#         "year": str(year),
#         "month": str(month),
#         "action": "search"
#     }

#     tables_data = {}

#     with requests.Session() as session:
#         session.headers.update(headers)
#         session.get(url)

#         response = session.post(url, data=payload)
#         response.raise_for_status()
#         soup = BeautifulSoup(response.content, "html.parser")

#         all_elements = soup.find_all(['strong', 'b', 'table'])

#         current_title = "Untitled Section"
#         table_count = 0

#         for el in all_elements:
#             if el.name in ['strong', 'b']:
#                 title_text = el.get_text(strip=True)
#                 if title_text:
#                     current_title = title_text
#             elif el.name == 'table' and 'statistics-table' in el.get('class', []):
#                 table_count += 1
#                 rows = []
#                 for row in el.find_all("tr"):
#                     cols = [col.get_text(strip=True) for col in row.find_all(["td", "th"])]
#                     if cols:
#                         rows.append(cols)
#                 tables_data[f"{table_count:02d} - {current_title}"] = rows

#     return tables_data

import requests
from bs4 import BeautifulSoup

def fetch_tables_with_titles_no_session(pmr_id, year, month):
    url = "https://www.sebi.gov.in/sebiweb/other/OtherAction.do?doPmr=yes"

    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": url,
        "Origin": "https://www.sebi.gov.in"
    }

    payload = {
        "pmrId": pmr_id,
        "year": str(year),
        "month": str(month),
        "action": "search"
    }

    # First: GET request to fetch cookies (and possibly CSRF token)
    get_response = requests.get(url, headers=headers)
    get_response.raise_for_status()

    # Extract cookies from the GET response
    cookies = get_response.cookies

    # Second: POST request with the same headers and cookies
    post_response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    post_response.raise_for_status()

    soup = BeautifulSoup(post_response.content, "html.parser")

    all_elements = soup.find_all(['strong', 'b', 'table'])
    current_title = "Untitled Section"
    table_count = 0
    tables_data = {}

    for el in all_elements:
        if el.name in ['strong', 'b']:
            title_text = el.get_text(strip=True)
            if title_text:
                current_title = title_text
        elif el.name == 'table' and 'statistics-table' in el.get('class', []):
            table_count += 1
            rows = []
            for row in el.find_all("tr"):
                cols = [col.get_text(strip=True) for col in row.find_all(["td", "th"])]
                if cols:
                    rows.append(cols)
            tables_data[f"{table_count:02d} - {current_title}"] = rows

    return tables_data



def extract_funds_inflow_outflow_table(tables_dict):
    target_key = None
    for key in tables_dict.keys():
        if "07 - C.Funds Inflow/ Outflow" in key:
            target_key = key
            break
    
    if target_key is None:
        return None  # Table not found
    
    data = tables_dict[target_key]

    # Try to find the header row with max columns
    max_cols = max(len(row) for row in data)
    
    # Find a header row with max columns (instead of just first row)
    header_row_index = 0
    for i, row in enumerate(data):
        if len(row) == max_cols:
            header_row_index = i
            break
    
    columns = data[header_row_index]
    # Data rows are everything after header row
    df = pd.DataFrame(data[header_row_index+1:], columns=columns)
    return df



def fetch_monthly_funds_data(pmr_id, months_list):
    """
    Fetch "07 - C.Funds Inflow/ Outflow" table data for multiple months.
    months_list: list of (year, month) tuples.
    Returns dict { "Month Year": DataFrame }
    """
    all_data = {}

    for year, month in months_list:
        month_name = calendar.month_name[month]
        month_year = f"{month_name} {year}"
        print(f"Fetching data for {month_year}...")
        tables = fetch_tables_with_titles(pmr_id, year, month)
        df = extract_funds_inflow_outflow_table(tables)
        if df is not None:
            all_data[month_year] = df
        else:
            print(f"Warning: '07 - C.Funds Inflow/ Outflow' table not found for {month_year}")

    print("Fetching complete.")
    return all_data


# Example usage:

from tabulate import tabulate

if __name__ == "__main__":
    pmr_id = "INP000008464@@INP000008464@@1729 ADVISORS LLP"
    all_months = [(2024, m) for m in range(4, 13)] + [(2025, m) for m in range(1, 4)]

    monthly_funds_data = fetch_monthly_funds_data(pmr_id, all_months)

    for month_year, df in monthly_funds_data.items():
        print(f"\nData for {month_year}:")
        print(f"Columns: {df.columns.tolist()}\n")
        # Print a nicely formatted table of the first 5 rows
        print(tabulate(df.head(), headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# Fetching data for April 2024...
# Fetching data for May 2024...
# Fetching data for June 2024...
# Fetching data for July 2024...
# Fetching data for August 2024...
# Fetching data for September 2024...
# Fetching data for October 2024...
# Fetching data for November 2024...
# Fetching data for December 2024...
# Fetching data for January 2025...
# Fetching data for February 2025...
# Fetching data for March 2025...
# Fetching complete.
#
# Data for April 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to April 2024(in INR crores)', 'Outflow during the FY since April 01 to  April 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  April 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to April 2024(in INR crores) │   Outflow during the FY since April 01 to  April 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  April 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                    32.86 │                                         0 │                                                             32.86 │                                                              32.86 │                                                                    0 │                                                                                        32.86 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                    32.86 │                                         0 │                                                             32.86 │                                                              32.86 │                                                                    0 │                                                                                        32.86 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for May 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to May 2024(in INR crores)', 'Outflow during the FY since April 01 to  May 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  May 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to May 2024(in INR crores) │   Outflow during the FY since April 01 to  May 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  May 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                    43.22 │                                         0 │                                                             43.22 │                                                            76.08 │                                                                  0 │                                                                                      76.08 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                    43.22 │                                         0 │                                                             43.22 │                                                            76.08 │                                                                  0 │                                                                                      76.08 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for June 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to june 2024(in INR crores)', 'Outflow during the FY since April 01 to  june 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  june 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to june 2024(in INR crores) │   Outflow during the FY since April 01 to  june 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  june 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                     25.7 │                                         0 │                                                              25.7 │                                                            101.77 │                                                                   0 │                                                                                      101.77 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                     25.7 │                                         0 │                                                              25.7 │                                                            101.77 │                                                                   0 │                                                                                      101.77 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for July 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to july 2024(in INR crores)', 'Outflow during the FY since April 01 to  july 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  july 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to july 2024(in INR crores) │   Outflow during the FY since April 01 to  july 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  july 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  4.92143 │                                   2.10264 │                                                           2.81879 │                                                           106.694 │                                                             2.10523 │                                                                                     104.589 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  4.92143 │                                   2.10264 │                                                           2.81879 │                                                           106.694 │                                                             2.10523 │                                                                                     104.589 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for August 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to August 2024(in INR crores)', 'Outflow during the FY since April 01 to  August 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  August 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to August 2024(in INR crores) │   Outflow during the FY since April 01 to  August 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  August 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  123.095 │                                   2.76094 │                                                           120.334 │                                                             229.789 │                                                               4.90445 │                                                                                       224.884 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  123.095 │                                   2.76094 │                                                           120.334 │                                                             229.789 │                                                               4.90445 │                                                                                       224.884 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for September 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to September 2024(in INR crores)', 'Outflow during the FY since April 01 to  September 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  September 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to September 2024(in INR crores) │   Outflow during the FY since April 01 to  September 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  September 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                   68.562 │                                   11.6735 │                                                           56.8884 │                                                                298.851 │                                                                  16.5408 │                                                                                           282.31 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                   68.562 │                                   11.6735 │                                                           56.8884 │                                                                298.851 │                                                                  16.5408 │                                                                                           282.31 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for October 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to October 2024(in INR crores)', 'Outflow during the FY since April 01 to  October 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  October 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to October 2024(in INR crores) │   Outflow during the FY since April 01 to  October 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  October 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  20.4847 │                                   7.33292 │                                                           13.1518 │                                                              319.336 │                                                                23.8737 │                                                                                        295.462 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  20.4847 │                                   7.33292 │                                                           13.1518 │                                                              319.336 │                                                                23.8737 │                                                                                        295.462 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for November 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to November 2024(in INR crores)', 'Outflow during the FY since April 01 to  November 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  November 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to November 2024(in INR crores) │   Outflow during the FY since April 01 to  November 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  November 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  8.59546 │                                   0.04875 │                                                           8.54671 │                                                               327.931 │                                                                 23.9225 │                                                                                         304.009 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  8.59546 │                                   0.04875 │                                                           8.54671 │                                                               327.931 │                                                                 23.9225 │                                                                                         304.009 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for December 2024:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to December 2024(in INR crores)', 'Outflow during the FY since April 01 to  December 2024(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  December 2024(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to December 2024(in INR crores) │   Outflow during the FY since April 01 to  December 2024(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  December 2024(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  12.1618 │                                   1.75109 │                                                           10.4108 │                                                               340.093 │                                                                 25.6735 │                                                                                         314.419 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  12.1618 │                                   1.75109 │                                                           10.4108 │                                                               340.093 │                                                                 25.6735 │                                                                                         314.419 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for January 2025:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to January 2025(in INR crores)', 'Outflow during the FY since April 01 to  January 2025(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  January 2025(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to January 2025(in INR crores) │   Outflow during the FY since April 01 to  January 2025(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  January 2025(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  2.34586 │                                         1 │                                                           1.34586 │                                                              342.439 │                                                                26.6735 │                                                                                        315.765 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  2.34586 │                                         1 │                                                           1.34586 │                                                              342.439 │                                                                26.6735 │                                                                                        315.765 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for February 2025:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to February 2025(in INR crores)', 'Outflow during the FY since April 01 to  February 2025(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  February 2025(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to February 2025(in INR crores) │   Outflow during the FY since April 01 to  February 2025(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  February 2025(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                  17.3541 │                                   1.20351 │                                                           16.1505 │                                                               359.803 │                                                                 27.8872 │                                                                                         331.916 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                  17.3541 │                                   1.20351 │                                                           16.1505 │                                                               359.803 │                                                                 27.8872 │                                                                                         331.916 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════╛
#
# Data for March 2025:
# Columns: ['', 'Inflow during the month(in INR crores)', 'Outflow during the month(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores)', 'Inflow during the FY since April 01 to March 2025(in INR crores)', 'Outflow during the FY since April 01 to  March 2025(in INR crores)', 'Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  March 2025(in INR crores)']
#
# ╒══════════════════════════════════╤══════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
# │                                  │   Inflow during the month(in INR crores) │   Outflow during the month(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the month(in INR crores) │   Inflow during the FY since April 01 to March 2025(in INR crores) │   Outflow during the FY since April 01 to  March 2025(in INR crores) │   Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to  March 2025(in INR crores) │
# ╞══════════════════════════════════╪══════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ 1729 FUNDAMENTAL VALUE INVESTING │                                    1.105 │                                   2.44173 │                                                          -1.33673 │                                                            360.908 │                                                              30.3289 │                                                                                      330.579 │
# ├──────────────────────────────────┼──────────────────────────────────────────┼───────────────────────────────────────────┼───────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Total                            │                                    1.105 │                                   2.44173 │                                                          -1.33673 │                                                            360.908 │                                                              30.3289 │                                                                                      330.579 │
# ╘══════════════════════════════════╧══════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════╛

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import calendar
import matplotlib.pyplot as plt

def fetch_only_funds_inflow_outflow(pmr_id, year, month):
    import requests
    from bs4 import BeautifulSoup

    url = "https://www.sebi.gov.in/sebiweb/other/OtherAction.do?doPmr=yes"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": url,
        "Origin": "https://www.sebi.gov.in"
    }
    payload = {
        "pmrId": pmr_id,
        "year": str(year),
        "month": str(month),
        "action": "search"
    }

    # 1. Make initial GET request to get cookies
    get_response = requests.get(url, headers=headers)
    get_response.raise_for_status()
    cookies = get_response.cookies

    # 2. Make POST request with cookies from GET and same headers
    post_response = requests.post(url, data=payload, headers=headers, cookies=cookies)
    post_response.raise_for_status()

    soup = BeautifulSoup(post_response.content, "html.parser")
    all_elements = soup.find_all(['strong', 'b', 'table'])

    current_title = "Untitled Section"
    table_count = 0

    for el in all_elements:
        if el.name in ['strong', 'b']:
            title_text = el.get_text(strip=True)
            if title_text:
                current_title = title_text
        elif el.name == 'table' and 'statistics-table' in el.get('class', []):
            table_count += 1
            full_title = f"{table_count:02d} - {current_title}"
            if full_title.strip() == "07 - C.Funds Inflow/ Outflow":
                rows = []
                for row in el.find_all("tr"):
                    cols = [col.get_text(strip=True) for col in row.find_all(["td", "th"])]
                    if cols:
                        rows.append(cols)
                return {full_title: rows}

    return {}  # If not found






def extract_funds_inflow_outflow_table(tables_dict):
    target_key = None
    for key in tables_dict.keys():
        if "07 - C.Funds Inflow/ Outflow" in key:
            target_key = key
            break
    if target_key is None:
        return None
    data = tables_dict[target_key]
    print("data : ",data)
    max_cols = max(len(row) for row in data)
    header_row_index = 0
    for i, row in enumerate(data):
        if len(row) == max_cols:
            header_row_index = i
            break
    columns = data[header_row_index]
    print("columns : ",columns)
    df = pd.DataFrame(data[header_row_index+1:], columns=columns)
    return df


def fetch_monthly_funds_data(pmr_id, months_list):
    all_data = {}
    for year, month in months_list:
        month_name = calendar.month_name[month]
        month_year = f"{month_name} {year}"
        print(f"Fetching data for {month_year}...")
        tables = fetch_only_funds_inflow_outflow(pmr_id, year, month)
        df = extract_funds_inflow_outflow_table(tables)
        if df is not None:
            all_data[month_year] = df
        else:
            print(f"Warning: '07 - C.Funds Inflow/ Outflow' table not found for {month_year}")
    print("Fetching complete.")
    return all_data


def prepare_performance_data(monthly_funds_data):
    months = []
    monthly_net_flow = []
    cumulative_net_flow = []

    for month_year in sorted(monthly_funds_data.keys(), key=lambda x: pd.to_datetime(x, format='%B %Y')):
        df = monthly_funds_data[month_year]
        df.columns = [col.strip() for col in df.columns]
        print(f"Processing {month_year}...")
        print("Columns:", df.columns.tolist())
        
        total_row = df[df[''].str.lower() == 'total']
        if total_row.empty:
            print(f"Warning: Total row not found for {month_year}, skipping.")
            continue

        # Look for columns containing the needed text ignoring FY end date variance
        monthly_col = None
        cumulative_col = None
        for col in df.columns:
            if "Net Inflow (+ve)/ Outflow (-ve) during the month" in col:
                monthly_col = col
            if "Net Inflow (+ve)/ Outflow (-ve) during the FY since April 01 to" in col:
                cumulative_col = col

        if not monthly_col or not cumulative_col:
            print(f"Warning: Required columns not found for {month_year}, skipping.")
            continue

        try:
            monthly_net = float(total_row.iloc[0][monthly_col].replace(',', ''))
            cumulative_net = float(total_row.iloc[0][cumulative_col].replace(',', ''))
        except Exception as e:
            print(f"Error parsing numbers for {month_year}: {e}, skipping.")
            continue
        
        print(f"Extracted values - Monthly: {monthly_net}, Cumulative: {cumulative_net}")

        months.append(month_year)
        monthly_net_flow.append(monthly_net)
        cumulative_net_flow.append(cumulative_net)

    print("Final extracted months:", months)
    return months, monthly_net_flow, cumulative_net_flow



def plot_performance_chart(months, monthly_net_flow, cumulative_net_flow):
    plt.figure(figsize=(12,6))
    plt.plot(months, monthly_net_flow, marker='o', label='Monthly Net Inflow/Outflow')
    plt.plot(months, cumulative_net_flow, marker='s', label='Cumulative Net Inflow/Outflow FY')
    plt.xticks(rotation=45)
    plt.title("Funds Inflow/Outflow Performance (Apr 2024 - Mar 2025)")
    plt.xlabel("Month")
    plt.ylabel("Amount (INR crores)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    pmr_id = "INP000008464@@INP000008464@@1729 ADVISORS LLP"
    all_months = [(2024, m) for m in range(4, 13)] + [(2025, m) for m in range(1, 4)]
    print("all_months : ",all_months)
    monthly_funds_data = fetch_monthly_funds_data(pmr_id, all_months)
    # print("monthly_funds_data : ",monthly_funds_data)

    months, monthly_net_flow, cumulative_net_flow = prepare_performance_data(monthly_funds_data)
    print("months, monthly_net_flow, cumulative_net_flow : ",months, monthly_net_flow, cumulative_net_flow )
    plot_performance_chart(months, monthly_net_flow, cumulative_net_flow)
# Out:
# all_months :  [(2024, 4), (2024, 5), (2024, 6), (2024, 7), (2024, 8), (2024, 9), (2024, 10), (2024, 11), (2024, 12), (2025, 1), (2025, 2), (2025, 3)]
